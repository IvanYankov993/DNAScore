# %%
# https://stackoverflow.com/questions/44116194/import-a-function-from-another-ipynb-file

# %% [markdown]
# # Modules

# %%
import numpy as np
import pandas as pd
import pathlib
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('agg')
import glob
import random

# import tensorflow as tf
# import keras_tuner as kt
# from tensorflow import keras
# from tensorflow.keras import Input, Model
# from tensorflow.keras import layers, models, initializers, optimizers
# from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, CSVLogger

# # Check if these are in model
# from tensorflow.keras.losses import Reduction 
# # from tensorflow import tensorflow.keras.losses.Reduction
# # from tensorflow.keras.losses import Loss
# from tensorflow.keras.losses import MeanAbsoluteError
# # Finish check


# from scikeras.wrappers import KerasRegressor

# import sklearn
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

from sklearn import metrics
from sklearn import datasets
from sklearn.metrics import make_scorer


import os
import pathlib

# %%
from sklearn import neighbors
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
import pickle as pk

# %%
# tf.__version__

# %% [markdown]
# # Functions

# %% [markdown]
# ## Loading Data from CSV file

# %%
def padding(X_descr_train_scaled):
#     Padding function so X data is always 250 dimensions
# Must be coupled with load_data. NB! double check if the scalling is not affected
# https://www.geeksforgeeks.org/python-call-function-from-another-function/
    a=X_descr_train_scaled.to_numpy()
    b=np.zeros((len(X_descr_train_scaled), 
                (250-int(X_descr_train_scaled.to_numpy().shape[1]))
               )
              )
    padded=np.concatenate((a,b),
                           axis=1, 
                          out=None, 
                          dtype=None
                         )
    return padded

# %%
def df_np(y):
#     y is a list
    y_out=[]
    for y_i in y:
        y_ic=y_i.to_numpy()
        y_ic=y_ic.reshape(y_ic.shape[0])
        y_out.append(y_ic)
    return y_out

# %%
def load_data(file,prop):
# Universal funciton for loading
# y_1, y_2, y_3, y_4 and x data from input csv (All, Train, Val or Train)
    y_1 = file[['dH']].copy()
    y_2 = file[['dS']].copy()
    y_3 = file[['dG']].copy()
    y_4 = file[['Tm']].copy()
    
    # Convert y data into required input shape
    y_1 = y_1.to_numpy()
    y_1 = y_1.reshape(y_1.shape[0])
    y_2 = y_2.to_numpy()
    y_2 = y_2.reshape(y_2.shape[0])
    y_3 = y_3.to_numpy()
    y_3 = y_3.reshape(y_3.shape[0])
    y_4 = y_4.to_numpy()
    y_4 = y_4.reshape(y_4.shape[0])
    
    # Load features based on prop
    X = file[[col for col in file.columns if f'{prop}_'in col]]
    
    return y_1, y_2, y_3, y_4, padding(X), X

# %%
def load_data_df(file,prop):
# Universal funciton for loading
# y_1, y_2, y_3, y_4 and x data from input csv (All, Train, Val or Train)
    y_1 = file[['dH']].copy()
    y_2 = file[['dS']].copy()
    y_3 = file[['dG']].copy()
    y_4 = file[['Tm']].copy()
    
    # Load features based on prop
    X = file[[col for col in file.columns if f'{prop}_'in col]]
    
    return y_1, y_2, y_3, y_4, X

# %%
def wrapped_train_test_split(train_idx,test_idx,file,prop):
#     capittal Y and X stand for pandas dataframe like file
    Y_1, Y_2, Y_3, Y_4, X = load_data_df(file,prop)

    # Separate data into training and test sets:
    x_train = X.iloc[train_idx]
    x_test = X.iloc[test_idx]
#     The next two lines (y) will vary depending on the CNN output
    y_train = [Y_1.iloc[train_idx],Y_2.iloc[train_idx],Y_3.iloc[train_idx],Y_4.iloc[train_idx]]
    y_test  = [Y_1.iloc[test_idx] ,Y_2.iloc[test_idx] ,Y_3.iloc[test_idx] ,Y_4.iloc[test_idx]]
    
    return padding(x_train), padding(x_test), df_np(y_train), df_np(y_test)

def wrapped_train_test_split_no_padding(train_idx,test_idx,file,prop):
#     capittal Y and X stand for pandas dataframe like file
    Y_1, Y_2, Y_3, Y_4, X = load_data_df(file,prop)

    # Separate data into training and test sets:
    x_train = X.iloc[train_idx]
    x_test = X.iloc[test_idx]
#     The next two lines (y) will vary depending on the CNN output
    y_train = [Y_1.iloc[train_idx],Y_2.iloc[train_idx],Y_3.iloc[train_idx],Y_4.iloc[train_idx]]
    y_test  = [Y_1.iloc[test_idx] ,Y_2.iloc[test_idx] ,Y_3.iloc[test_idx] ,Y_4.iloc[test_idx]]
    
    return x_train, x_test, df_np(y_train), df_np(y_test)

# %% [markdown]
# ## Stats and Tensor_stats

# %%
def r2_func(y_true, y_pred, **kwargs):
    return metrics.r2_score(y_true, y_pred)
def rmse_func(y_true, y_pred, **kwargs):
    return np.sqrt(metrics.mean_squared_error(y_true, y_pred))  
def bias_func(y_true, y_pred, **kwargs):
    return np.mean(y_true-y_pred)
def sdep_func(y_true, y_pred, **kwargs):
    return (np.mean((y_true-y_pred-(np.mean(y_true-y_pred)))**2))**0.5
#these 4 are for tensorflow formats
def r2_func_tf(y_true, y_pred, **kwargs):
    numerator = tf.reduce_sum(tf.square(y_true - y_pred))
    denominator = tf.reduce_sum(tf.square(y_true - tf.reduce_mean(y_true)))
    r2 = 1 - numerator / denominator
    return r2
def rmse_func_tf(y_true, y_pred, **kwargs):
    mse = tf.reduce_mean(tf.square(y_true - y_pred))
    rmse = tf.sqrt(mse)
    return rmse
def bias_func_tf(y_true, y_pred, **kwargs):
    bias = tf.reduce_mean(y_true - y_pred)
    return bias
def sdep_func_tf(y_true, y_pred, **kwargs):
    diff = y_true - y_pred
    mean_diff = tf.reduce_mean(diff)
    sdep = tf.sqrt(tf.reduce_mean(tf.square(diff - mean_diff)))
    return sdep

# %%
def save_splits(idx,true,pred,resample,path,split_type):
    y_outputs = pd.DataFrame()
    y_outputs['ID'] = idx
    y_outputs['y_true'] = true
    y_outputs['y_pred'] = pred
    y_outputs.to_csv(f'{path}/Split_{resample}_type_{split_type}.csv', index=False)
    return

# %%
def create_dir(home,resample,model_name,prop,GSHT):
    if home==None:
        home=os.getcwd()
    try:
            os.mkdir("{}/CV/".format(home))
    except:
            pass
    os.chdir("{}/CV/".format(home))
    try:
        os.mkdir("{}".format(resample))
    except:
            pass
    os.chdir("{}".format(resample))
    try:
        os.mkdir("{}".format(model_name))
    except:
            pass
    os.chdir("{}".format(model_name))
    try:
        os.mkdir("{}".format(prop))
    except:
            pass
    os.chdir("{}".format(prop))
    try:
        os.mkdir("{}".format(GSHT))
    except:
            pass
    os.chdir("{}".format(GSHT))

    os.chdir("{}".format(home))
    return

# %% [markdown]
# # Model

# %% [markdown]
# ## hp

# %%
# largest input shape is 250

# %%
def build_model(hp):
    
#     Hyper parameters
    # hp_activation= hp.Choice('activation', values=['relu','tanh'])           
    # model_type1 = hp.Choice("model_type1", ["CNN1", "CNN2","CNN3"])
    # model_type = hp.Choice("model_type", ["Dense1", "Dense2","Dense3"])
    model_type1 = hp.Choice("model_type1", ["CNN3"])
    model_type = hp.Choice("model_type", ["Dense3"])
    
#     INPUT for NN
    
    inputs = keras.Input(shape=(250,1))
    x_layer=inputs
    
#     MANDATORY CNN (optional to move into first condition hp.cond_scope
    
    x_layer = keras.layers.Conv1D(32, 
                        kernel_size=(3), 
                        strides=(2), 
                        padding='valid', 
                        activation='relu', 
                        input_shape=(250,1),
                        name = 'conv1d_1'
                        )(x_layer)
    x_layer = keras.layers.MaxPooling1D((2), name = 'maxpooling_1')(x_layer)
    x_layer = keras.layers.BatchNormalization(name = 'batchnorm_1')(x_layer)
    
# #     CONDITIONAL CONVOLUTION LAYERS (Consider moving the above into CNN1) test 0-3 CNN and 0-3 Dense
#     with hp.conditional_scope("model_type1", ["CNN1"]):
#             if model_type1 == "CNN1":
#                 pass
    
#     with hp.conditional_scope("model_type1", ["CNN2"]):
#             if model_type1 == "CNN2":
#                 x = keras.layers.Conv1D(32, 
#                                     kernel_size=(3), 
#                                     strides=(2), 
#                                     padding='valid', 
#                                     activation='relu', 
#                                     name = f'conv1d_2'
#                                     )(x)
#                 x = keras.layers.MaxPooling1D((2), name = f'maxpooling_2')(x)
#                 x = keras.layers.BatchNormalization(name = f'batchnorm_2')(x)
                
    with hp.conditional_scope("model_type1", ["CNN3"]):
            if model_type1 == "CNN3":
                x_layer = keras.layers.Conv1D(32, 
                                    kernel_size=(3), 
                                    strides=(2), 
                                    padding='valid', 
                                    activation='relu', 
                                    name = f'conv1d_2'
                                    )(x_layer)
                x_layer = keras.layers.MaxPooling1D((2), name = f'maxpooling_2')(x_layer)
                x_layer = keras.layers.BatchNormalization(name = f'batchnorm_2')(x_layer)
                
                x_layer = keras.layers.Conv1D(32, 
                                    kernel_size=(3), 
                                    strides=(2), 
                                    padding='valid', 
                                    activation='relu', 
                                    name = f'conv1d_3'
                                    )(x_layer)
                x_layer = keras.layers.MaxPooling1D((2), name = f'maxpooling_3')(x_layer)
                x_layer = keras.layers.BatchNormalization(name = f'batchnorm_3')(x_layer)
                
#     FLATTEN AFTER CONVOLUTIONS
    x_layer = keras.layers.Flatten(name = 'flatten')(x_layer)
    
#     CONDITIONAL DENSE LAYERS
    
    # with hp.conditional_scope("model_type", ["Dense1"]):
    #     if model_type == "Dense1":
    #         hp_layer_1= hp.Choice(f'layer_1', values=[16,32,64,128])

    #         x = keras.layers.Dense(
    #                     hp_layer_1,
    #                     activation='relu',
    #                     use_bias=True,
    #                     # name='layer_1',
    #                     kernel_initializer='glorot_uniform',
    #                     bias_initializer='zeros',
    #                     kernel_regularizer=None,
    #                     bias_regularizer=None,
    #                     activity_regularizer=None,
    #                     kernel_constraint=None,
    #                     bias_constraint=None
    #                 )(x)
    # with hp.conditional_scope("model_type", ["Dense2"]):
    #     if model_type == "Dense2":
    #         hp_layer_2_1= hp.Choice(f'layer_2_1', values=[16,32,64,128])

    #         x = keras.layers.Dense(
    #                     hp_layer_2_1,
    #                     activation='relu',
    #                     use_bias=True,
    #                     kernel_initializer='glorot_uniform',
    #                     bias_initializer='zeros',
    #                     kernel_regularizer=None,
    #                     bias_regularizer=None,
    #                     activity_regularizer=None,
    #                     kernel_constraint=None,
    #                     bias_constraint=None
    #                 )(x)
    #         hp_layer_2_2= hp.Choice(f'layer_2_2', values=[16,32,64,128])

    #         x = keras.layers.Dense(
    #                     hp_layer_2_2,
    #                     activation='relu',
    #                     use_bias=True,
    #                     kernel_initializer='glorot_uniform',
    #                     bias_initializer='zeros',
    #                     kernel_regularizer=None,
    #                     bias_regularizer=None,
    #                     activity_regularizer=None,
    #                     kernel_constraint=None,
    #                     bias_constraint=None
    #                 )(x)

    with hp.conditional_scope("model_type", ["Dense3"]):
        if model_type == "Dense3":
            hp_layer_3_1= hp.Choice(f'layer_3_1', values=[32])
            # [16,32,64,128]

            x_layer = keras.layers.Dense(
                        hp_layer_3_1,
                        activation='relu',
                        use_bias=True,
                        kernel_initializer='glorot_uniform',
                        bias_initializer='zeros',
                        kernel_regularizer=None,
                        bias_regularizer=None,
                        activity_regularizer=None,
                        kernel_constraint=None,
                        bias_constraint=None
                    )(x_layer)
            hp_layer_3_2= hp.Choice(f'layer_3_2',  values=[32])
            # [16,32,64,128]
            x_layer = keras.layers.Dense(
                                hp_layer_3_2,
                                activation='relu',
                                use_bias=True,
                                kernel_initializer='glorot_uniform',
                                bias_initializer='zeros',
                                kernel_regularizer=None,
                                bias_regularizer=None,
                                activity_regularizer=None,
                                kernel_constraint=None,
                                bias_constraint=None
                            )(x_layer)
            hp_layer_3_3= hp.Choice(f'layer_3_3',  values=[2,32])
            # [16,32,64,128]
            
            x_layer = keras.layers.Dense(
                        hp_layer_3_3,
                        activation='relu',
                        use_bias=True,
                        kernel_initializer='glorot_uniform',
                        bias_initializer='zeros',
                        kernel_regularizer=None,
                        bias_regularizer=None,
                        activity_regularizer=None,
                        kernel_constraint=None,
                        bias_constraint=None
                    )(x_layer)
#     OUTPUT LAYERS

    output_1 = keras.layers.Dense(1, name='enthalpy_pred')(x_layer)
    # output_2 = keras.layers.Dense(1, name='entropy_pred')(x)
    # output_3 = keras.layers.Dense(1, name='free_energy_pred')(x)

    # model = Model(inputs=inputs, outputs=[output_1, output_2, output_3])
    model = Model(inputs=inputs, outputs=output_1)
    
#     SETTINGS
#     SETTINGS

#     ADAPTIVE LEARNING RATE   
    
    initial_learning_rate = 0.01
    decay_steps = 10.0
    decay_rate = 0.5
    learning_rate_fn = keras.optimizers.schedules.InverseTimeDecay(
                                    initial_learning_rate, decay_steps, decay_rate)
    
#     SETTING ADAM OPTIMISER
    optimiser = tf.keras.optimizers.Adam(learning_rate=learning_rate_fn)
    
#     COMPILE MODEl
    model.compile(loss = "mse" , 
                  optimizer = optimiser, 
                  metrics = ["mse",'mean_absolute_error',r2_func_tf, rmse_func_tf, bias_func_tf, sdep_func_tf])   
    
    return model

# %% [markdown]
# ## Jonnys

# %%
def build_model(dense1,dense2,dense3,**kwargs):
    
    print("dense1: ", dense1)
    
    print("dense2: ", dense2)
    
    print("dense3: ", dense3)
    
    model = keras.Sequential([
        #first convolution triplet
        layers.Conv1D(32,
                    kernel_size=(3),
                    strides=(2),
                    padding='valid',
                    activation='relu',
                    # input_shape=np.expand_dims((160,1), axis=0)),
                    input_shape=(250,1)),
                    # input_shape=(1,160,1)),
        layers.MaxPooling1D((2)),
        layers.BatchNormalization(),

        #second convolution triplet
        layers.Conv1D(32,
                    kernel_size=(3),
                    strides=(2),
                    padding='valid',
                    activation='relu'),
        layers.MaxPooling1D((2)),
        layers.BatchNormalization(),

        #third convolution triplet
        layers.Conv1D(32,
                    kernel_size=(3),
                    strides=(2),
                    padding='valid',
                    activation='relu'),
        layers.MaxPooling1D((2)),
        layers.BatchNormalization(),

        #flatten layer - will have shape (1248, 1)
        layers.Flatten(),

        #4 dense layers
        #the first 3 are hidden layers which have half the number of nodes of the previous layer
        #the 4th layer is the output
        
        
        
        layers.Dense(dense1, activation='relu'),
        layers.Dense(dense2, activation='relu'),
        layers.Dense(dense3, activation='relu'),
        layers.Dense(1)
    ])

    #setting adam optimiser
    optimiser = tf.keras.optimizers.Adam(learning_rate=1e-4)

    #compiling model
    model.compile(loss='mse',
                optimizer=optimiser,
                metrics=['mse', r2_func_tf, rmse_func_tf, bias_func_tf, sdep_func_tf])

    return model

# %% [markdown]
# ## Ivan

# %%
def build_model(dense1,dense2,dense3,**kwargs):
    
    print("dense1: ", dense1)
    
    print("dense2: ", dense2)
    
    print("dense3: ", dense3)
    
# #     Hyper parameters
#     # hp_activation= hp.Choice('activation', values=['relu','tanh'])           
#     model_type1 = hp.Choice("model_type1", ["CNN1", "CNN2","CNN3"])
#     model_type = hp.Choice("model_type", ["Dense1", "Dense2","Dense3"])
    
#     INPUT for NN
    
    inputs = keras.Input(shape=(250,1))
    x=inputs
    
#     MANDATORY CNN (optional to move into first condition hp.cond_scope
    
    x = keras.layers.Conv1D(32, 
                        kernel_size=(3), 
                        strides=(2), 
                        padding='valid', 
                        activation='relu', 
                        input_shape=(250,1),
                        name = 'conv1d_1'
                        )(x)
    x = keras.layers.MaxPooling1D((2), name = 'maxpooling_1')(x)
    x = keras.layers.BatchNormalization(name = 'batchnorm_1')(x)
    
#     CONDITIONAL CONVOLUTION LAYERS (Consider moving the above into CNN1) test 0-3 CNN and 0-3 Dense
    # with hp.conditional_scope("model_type1", ["CNN1"]):
    #         if model_type1 == "CNN1":
    #             pass
    
    # with hp.conditional_scope("model_type1", ["CNN2"]):
    #         if model_type1 == "CNN2":
    #             x = keras.layers.Conv1D(32, 
    #                                 kernel_size=(3), 
    #                                 strides=(2), 
    #                                 padding='valid', 
    #                                 activation='relu', 
    #                                 name = f'conv1d_2'
    #                                 )(x)
    #             x = keras.layers.MaxPooling1D((2), name = f'maxpooling_2')(x)
    #             x = keras.layers.BatchNormalization(name = f'batchnorm_2')(x)
    x = keras.layers.Conv1D(32, 
                        kernel_size=(3), 
                        strides=(2), 
                        padding='valid', 
                        activation='relu', 
                        name = f'conv1d_2'
                        )(x)
    x = keras.layers.MaxPooling1D((2), name = f'maxpooling_2')(x)
    x = keras.layers.BatchNormalization(name = f'batchnorm_2')(x)   
    
    # with hp.conditional_scope("model_type1", ["CNN3"]):
    #         if model_type1 == "CNN3":
    #             x = keras.layers.Conv1D(32, 
    #                                 kernel_size=(3), 
    #                                 strides=(2), 
    #                                 padding='valid', 
    #                                 activation='relu', 
    #                                 name = f'conv1d_2'
    #                                 )(x)
    #             x = keras.layers.MaxPooling1D((2), name = f'maxpooling_2')(x)
    #             x = keras.layers.BatchNormalization(name = f'batchnorm_2')(x)
                
    #             x = keras.layers.Conv1D(32, 
    #                                 kernel_size=(3), 
    #                                 strides=(2), 
    #                                 padding='valid', 
    #                                 activation='relu', 
    #                                 name = f'conv1d_3'
    #                                 )(x)
    #             x = keras.layers.MaxPooling1D((2), name = f'maxpooling_3')(x)
    #             x = keras.layers.BatchNormalization(name = f'batchnorm_3')(x)
    
    x = keras.layers.Conv1D(32, 
                        kernel_size=(3), 
                        strides=(2), 
                        padding='valid', 
                        activation='relu', 
                        name = f'conv1d_3'
                        )(x)
    x = keras.layers.MaxPooling1D((2), name = f'maxpooling_3')(x)
    x = keras.layers.BatchNormalization(name = f'batchnorm_3')(x)            
#     FLATTEN AFTER CONVOLUTIONS
    x = keras.layers.Flatten(name = 'flatten')(x)
    
#     CONDITIONAL DENSE LAYERS
    
    # with hp.conditional_scope("model_type", ["Dense1"]):
    #     if model_type == "Dense1":
    #         hp_layer_1= hp.Choice(f'layer_1', values=[16,32,64,128])

    #         x = keras.layers.Dense(
    #                     hp_layer_1,
    #                     activation='relu',
    #                     use_bias=True,
    #                     # name='layer_1',
    #                     kernel_initializer='glorot_uniform',
    #                     bias_initializer='zeros',
    #                     kernel_regularizer=None,
    #                     bias_regularizer=None,
    #                     activity_regularizer=None,
    #                     kernel_constraint=None,
    #                     bias_constraint=None
    #                 )(x)
    
    x = keras.layers.Dense(
                dense1,
                activation='relu',
                use_bias=True,
                # name='layer_1',
                kernel_initializer='glorot_uniform',
                bias_initializer='zeros',
                kernel_regularizer=None,
                bias_regularizer=None,
                activity_regularizer=None,
                kernel_constraint=None,
                bias_constraint=None
            )(x)
    
    # with hp.conditional_scope("model_type", ["Dense2"]):
    #     if model_type == "Dense2":
    #         hp_layer_2_1= hp.Choice(f'layer_2_1', values=[16,32,64,128])

    #         x = keras.layers.Dense(
    #                     hp_layer_2_1,
    #                     activation='relu',
    #                     use_bias=True,
    #                     kernel_initializer='glorot_uniform',
    #                     bias_initializer='zeros',
    #                     kernel_regularizer=None,
    #                     bias_regularizer=None,
    #                     activity_regularizer=None,
    #                     kernel_constraint=None,
    #                     bias_constraint=None
    #                 )(x)
    #         hp_layer_2_2= hp.Choice(f'layer_2_2', values=[16,32,64,128])

    #         x = keras.layers.Dense(
    #                     hp_layer_2_2,
    #                     activation='relu',
    #                     use_bias=True,
    #                     kernel_initializer='glorot_uniform',
    #                     bias_initializer='zeros',
    #                     kernel_regularizer=None,
    #                     bias_regularizer=None,
    #                     activity_regularizer=None,
    #                     kernel_constraint=None,
    #                     bias_constraint=None
    #                 )(x)
    x = keras.layers.Dense(
                    dense2,
                    activation='relu',
                    use_bias=True,
                    kernel_initializer='glorot_uniform',
                    bias_initializer='zeros',
                    kernel_regularizer=None,
                    bias_regularizer=None,
                    activity_regularizer=None,
                    kernel_constraint=None,
                    bias_constraint=None
                )(x)

    # with hp.conditional_scope("model_type", ["Dense3"]):
    #     if model_type == "Dense3":
    #         hp_layer_3_1= hp.Choice(f'layer_3_1', values=[16,32,64,128])

    #         x = keras.layers.Dense(
    #                     hp_layer_3_1,
    #                     activation='relu',
    #                     use_bias=True,
    #                     kernel_initializer='glorot_uniform',
    #                     bias_initializer='zeros',
    #                     kernel_regularizer=None,
    #                     bias_regularizer=None,
    #                     activity_regularizer=None,
    #                     kernel_constraint=None,
    #                     bias_constraint=None
    #                 )(x)
    #         hp_layer_3_2= hp.Choice(f'layer_3_2', values=[16,32,64,128])

    #         x = keras.layers.Dense(
    #                             hp_layer_3_2,
    #                             activation='relu',
    #                             use_bias=True,
    #                             kernel_initializer='glorot_uniform',
    #                             bias_initializer='zeros',
    #                             kernel_regularizer=None,
    #                             bias_regularizer=None,
    #                             activity_regularizer=None,
    #                             kernel_constraint=None,
    #                             bias_constraint=None
    #                         )(x)
    #         hp_layer_3_3= hp.Choice(f'layer_3_3', values=[16,32,64,128])

    #         x = keras.layers.Dense(
    #                     hp_layer_3_3,
    #                     activation='relu',
    #                     use_bias=True,
    #                     kernel_initializer='glorot_uniform',
    #                     bias_initializer='zeros',
    #                     kernel_regularizer=None,
    #                     bias_regularizer=None,
    #                     activity_regularizer=None,
    #                     kernel_constraint=None,
    #                     bias_constraint=None
    #                 )(x)

    x = keras.layers.Dense(
                    dense3,
                    activation='relu',
                    use_bias=True,
                    kernel_initializer='glorot_uniform',
                    bias_initializer='zeros',
                    kernel_regularizer=None,
                    bias_regularizer=None,
                    activity_regularizer=None,
                    kernel_constraint=None,
                    bias_constraint=None
                )(x)
#     OUTPUT LAYERS

    output_1 = keras.layers.Dense(1, name='enthalpy_pred')(x)
    # output_2 = keras.layers.Dense(1, name='entropy_pred')(x)
    # output_3 = keras.layers.Dense(1, name='free_energy_pred')(x)

    # model = Model(inputs=inputs, outputs=[output_1, output_2, output_3])
    model = Model(inputs=inputs, outputs=output_1)
    
#     SETTINGS
#     SETTINGS

#     ADAPTIVE LEARNING RATE   
    
    initial_learning_rate = 0.01
    decay_steps = 10.0
    decay_rate = 0.5
    learning_rate_fn = keras.optimizers.schedules.InverseTimeDecay(
                                    initial_learning_rate, decay_steps, decay_rate)
    
#     SETTING ADAM OPTIMISER
    optimiser = tf.keras.optimizers.Adam(learning_rate=learning_rate_fn)
    
#     COMPILE MODEl
    model.compile(loss = "mse" , 
                  optimizer = optimiser, 
                  metrics = ["mse",'mean_absolute_error',r2_func_tf, rmse_func_tf, bias_func_tf, sdep_func_tf])   
    
    return model

# %% [markdown]
# # Workflow

# %% [markdown]
# ## Navigation

# %%
__file__=os.path.abspath('CNN_jony')
rootdir = pathlib.Path(__file__).parent
datadir = rootdir/"Input"
resultdir = rootdir/"Outputs"

# %%
# sorted(pathlib.Path('.').glob('*'))

# %% [markdown]
# ## Load data

# %%
# Initialise
df_all=pd.DataFrame()
df1=pd.read_csv('resample_1_test_resample.csv')
df2=pd.read_csv('resample_1_train_resample.csv')
df3=pd.read_csv('resample_1_val_resample.csv')
# concatenate
df_all=pd.concat([df1,df2,df3])
# Check shape
print(df_all.shape, df1.shape, df2.shape, df3.shape)
# organise index
df_all=df_all.set_index('Index').sort_index()
# Save all data
df_all.to_csv("Lomzov_dataset_IY.csv",index=False)
# Load data from a CSV file
test_df=pd.read_csv("Lomzov_dataset_IY.csv")
# parameters to work with
file=test_df
prop='Granulated'
# obtain y and x data
y_1, y_2, y_3, y_4, x, X= load_data(file,prop)
# Out:
# (305, 384) (91, 384) (171, 384) (43, 384)

# %%
# x.shape
# X.shape
# y_1.shape
# Out:
# (305,)

# %% [markdown]
# ## Settings CV and Model

# %%
# input_dataset = pd.read_csv(f'{root_dir}/Descriptor_sets/Descriptors_Clusters_Y.csv')

desc_type = ['RF-Score','H-Bonding','Granulated','DNA-Groups','OHEP','LP_dec2','CountDNA','CountDNAp']

no_resamples = 1

cv_dir=["random_CV","stratified_CV"]

models_list = ["RF","KNN","st_1DCNN","mt3_1DCNN","mt4_1DCNN"]

resample=1

fold=2

# resample_folder=(f'{root_dir}/random_CV/resample_{resample}/resample_{resample}')

# fold_folder=(f'{root_dir}/random_CV/resample_{resample}/fold_{fold}')

# %%
###set global variables
#number of resamples, sfed_type, n_jobs, folds (might be redundant), epochs
n_resamples = 1
n_jobs = 1
# same
n_folds = 2
mc_cv = 2
# train test split
test_frac = 0.3
# 
epochs = 20

# %% [markdown]
# # Deep learning CNN

# %% [markdown]
# ## Pipe

# %% [markdown]
# ### Model

# %%
resample=1

# %%
# Keras call backs
# early stopping
# param_grid_model = {
#                  "model__dense1":[16],
#                  "model__dense2":[8],
#                  "model__dense3":[2,4,8,16]}

def model_for_grid(resultdir,resample,epochs):
#Needs variable epochs 
    es = EarlyStopping(monitor='val_loss', 
                       mode='min', 
                       verbose=1, 
                       patience=20, 
                       restore_best_weights=True)
    # CSV Logger
    csv_logger = CSVLogger(f"{resultdir}/csv_logger/model_history_log_resample_{resample}.csv", 
                           append=True)
    # CP_callbacks
    cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=f'{resultdir}/model_checkpoint/training_{resample}/cp.ckpt',
                                                     save_weights_only=True,
                                                     verbose=1)
    # TensorBoard
    tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=f'{resultdir}/tensorboard_logs/{resample}', #/{batch}', # _ADAPTIVELEARNIGNRATE_01_10_Dense3_64_3CNN_lr_3_es
                                                          update_freq = 1,
                                                          # histogram_freq=1, 
                                                          write_graph=False, 
                                                          write_images=False)
    # https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/TensorBoard
    
    # Covert to list and provide to Keras Regressor
    keras_callbacks = [es, csv_logger, cp_callback,tensorboard_callback]
    keras_callbacks = [es, csv_logger, tensorboard_callback]
    
    ###define parameter grid for hyperparameter optimisation
    # param_grid = {
    #              "dense1":[16,32],
    #              "dense2":[16,8],
    #              "dense3":[8,4]},
        
    ###initialise model
    model = KerasRegressor(model=build_model, 
                           batch=64,
                            epochs=epochs,
                            verbose=1,
                            validation_split=0.2,
                           callbacks=keras_callbacks,
                           dense1=1,
                            dense2=1,
                            dense3=1
                          )

    return model

# %%
def model_for_grid2(resultdir,resample,**kwargs):
    es = EarlyStopping(monitor='val_loss', 
                       mode='min', 
                       verbose=1, 
                       patience=20, 
                       restore_best_weights=True)
    # CSV Logger
    csv_logger = CSVLogger(f"{resultdir}/csv_logger/model_history_log_resample_{resample}.csv", 
                           append=True)
    # # CP_callbacks
    # cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=f'{resultdir}/model_checkpoint/training_{resample}/cp.ckpt',
    #                                                  save_weights_only=True,
    #                                                  verbose=1)
    # TensorBoard
    tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=f'{resultdir}/tensorboard_logs/', #/{batch}', # _ADAPTIVELEARNIGNRATE_01_10_Dense3_64_3CNN_lr_3_es
                                                          update_freq = 1,
                                                          # histogram_freq=1, 
                                                          write_graph=False, 
                                                          write_images=False)
    # https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/TensorBoard
    
    # Covert to list and provide to Keras Regressor
    # keras_callbacks = [es, csv_logger, cp_callback,tensorboard_callback]
    keras_callbacks = [es, csv_logger, tensorboard_callback]
        
    ###initialise model
    model = KerasRegressor(model=build_model, 
                           batch=16,
                            epochs=epochs,
                            verbose=1,
                            validation_split=0.3,
                           callbacks=keras_callbacks)
                           # dense1=1,
                           #  dense2=1,
                           #  dense3=1)
    return model

# %% [markdown]
# ### Scaller and Pipe

# %%
# Define inputs for pipe
scaler = StandardScaler()
epochs=20
model_name='model'
# Do we have to redefine the pipe? Think Dans code and data leakage
# NB! "model" must match the model__
pipe = Pipeline(steps=[("scaler", scaler), (f"{model_name}", model_for_grid(resultdir,resample,epochs))])

# NB! Thin whether {model_name} must be includded in the parameter grid

# %% [markdown]
# ### Grid

# %%
###define scoring dict for cv
scorers = {
    'r2':make_scorer(r2_func), 
    'rmse':make_scorer(rmse_func, greater_is_better=False), 
    'bias':make_scorer(bias_func, greater_is_better=False), 
    'sdep':make_scorer(sdep_func, greater_is_better=False)
    }


param_grid_model = {#"model__epochs":[epochs],
                     #"model__verbose=":[1],
                     #"model__validation_split":[0.2],
                     
                 "model__dense1":[32],
                 "model__dense2":[32],
                 "model__dense3":[2,32]}

param_grid_model = {#"model__epochs":[epochs],
                     #"model__verbose=":[1],
                     #"model__validation_split":[0.2],
                     
                 "dense1":[32],
                 "dense2":[32],
                 "dense3":[2,32]}
epochs=20
###create CV using sklearn.GridSearchCV
grid = GridSearchCV(
    # estimator=pipe, 
    estimator=model_for_grid(resultdir,resample,epochs),
    param_grid=param_grid_model,
    n_jobs=1, 
    cv=n_folds, 
    refit='rmse', 
    scoring=scorers, 
    return_train_score=True,
    
    )

# %% [markdown]
# ## Fit model

# %%
import time
# time_start=time.time()

# %%
mc_cv=1
n_folds=2
# Initialise train test split:
train_test_split = ShuffleSplit(mc_cv, test_size=test_frac, random_state=1)
epochs=100
# resample=0
# Monte Carlo CV:

time_start=time.time()
resample=0
for train_idx, test_idx in train_test_split.split(x):
    resample+=1
    
    x_train, x_test, y_train, y_test = wrapped_train_test_split(train_idx,test_idx,file,prop)
    
    ### DEFINE MODEL
    es = EarlyStopping(monitor='val_loss', 
                       mode='min', 
                       verbose=1, 
                       patience=20, 
                       restore_best_weights=True)
    # CSV Logger
    csv_logger = CSVLogger(f"{resultdir}/csv_logger/model_history_log_resample_{resample}.csv", 
                           append=True)
    # # CP_callbacks
    # cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=f'{resultdir}/model_checkpoint/training_{resample}/cp.ckpt',
    #                                                  save_weights_only=True,
    #                                                  verbose=1)
    # TensorBoard
    tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=f'{resultdir}/tensorboard_logs/', #/{batch}', # _ADAPTIVELEARNIGNRATE_01_10_Dense3_64_3CNN_lr_3_es
                                                          update_freq = 1,
                                                          # histogram_freq=1, 
                                                          write_graph=False, 
                                                          write_images=False)
    # https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/TensorBoard
    
    # Covert to list and provide to Keras Regressor
    # keras_callbacks = [es, csv_logger, cp_callback,tensorboard_callback]
    keras_callbacks = [es, csv_logger, tensorboard_callback]
        
    ###initialise model
    model = KerasRegressor(model=build_model, 
                           batch=16,
                            epochs=epochs,
                            verbose=1,
                            validation_split=0.3,
                           callbacks=keras_callbacks)
                           # dense1=1,
                           #  dense2=1,
                           #  dense3=1)

    ### PIPE
    # Define inputs for pipe
    scaler = StandardScaler()
 
    model_name='model'
    # Do we have to redefine the pipe? Think Dans code and data leakage
    # NB! "model" must match the model__
    # pipe = Pipeline(steps=[("scaler", scaler), (f"{model_name}", model )] )
    pipe = Pipeline(steps=[("scaler", scaler), (f"{model_name}",model_for_grid2(resultdir,resample))])
    # model_for_grid(resultdir,resample,epochs))])

    ###define scoring dict for cv
    scorers = {
        'r2':make_scorer(r2_func), 
        'rmse':make_scorer(rmse_func, greater_is_better=False), 
        'bias':make_scorer(bias_func, greater_is_better=False), 
        'sdep':make_scorer(sdep_func, greater_is_better=False)
        }
    ###parameter grid
    # param_grid_model = {                     
    #              "dense1":[32],
    #              "dense2":[32],
    #              "dense3":[2,32]}
    param_grid_model = {
                     "model__dense1":[32],
                     "model__dense2":[32],
                     "model__dense3":[2,32]}
    
    ###create CV using sklearn.GridSearchCV
    grid = GridSearchCV(
        estimator=pipe, 
        # estimator=model_for_grid(resultdir,resample,epochs),
        # estimator=model,
        param_grid=param_grid_model,
        n_jobs=1, 
        cv=n_folds, 
        refit='rmse', 
        scoring=scorers, 
        return_train_score=True,
        
        )
    batch=16
    #########################################
    # tuner = kt.GridSearch(build_model,
    #                    objective='val_loss',
    #                    # objective = ['val_mse','epoch_entropy_pred_mse','val_free_energy_pred_mse'],
    #                   directory=os.getcwd()+'/hyper_param_tunning_tunner',
    #                   overwrite=False,
    #                   project_name=f'{batch}')
     for hp_train_idx, hp_val_idx in train_test_split.split(pd.DataFrame(x_train)):
        x_hp_train, x_hp_val, y_hp_train, y_hp_val = wrapped_train_val_split(hp_train_idx,hp_val_idx,pd.DataFrame(x_train),y_train)
        tuner = kt.GridSearch(build_model,
                           objective='val_loss',
                           # objective = ['val_mse','epoch_entropy_pred_mse','val_free_energy_pred_mse'],
                          directory=os.getcwd()+'/hyper_param_tunning_tunner',
                          overwrite=False,
                          project_name=f'{batch}')
        tuner.search(x_hp_train, y_hp_train[0],
                    epochs = epochs,
                    batch_size=16,
                    verbose = 2,
                    validation_data =(x_hp_val, y_hp_val[0]),
                     # validation_split = 0.2,
                    callbacks=[es1, csv_logger1, cp_callback1, tensorboard_callback1])
    
    ###fit the model
    # history = grid.fit(x_train, y_train[0], 
    #                 # epochs=epochs,
    #                 # verbose=1,
    #                 # validation_split=0.2,
    #                 # callbacks=keras_callbacks1
    #                 )

   
        
total_time=time.time()-time_start
# Out:
# dense1:  32
# dense2:  32
# dense3:  2
# Epoch 1/100
# 3/3 [==============================] - 2s 150ms/step - loss: 5092.0811 - mse: 5092.0811 - mean_absolute_error: 67.5874 - r2_func_tf: -9.9051 - rmse_func_tf: 74.1293 - bias_func_tf: -70.4812 - sdep_func_tf: 22.8899 - val_loss: 4455.3789 - val_mse: 4455.3789 - val_mean_absolute_error: 64.3858 - val_r2_func_tf: -13.3122 - val_rmse_func_tf: 66.7486 - val_bias_func_tf: -64.3858 - val_sdep_func_tf: 17.6023
# Epoch 2/100
# 3/3 [==============================] - 0s 33ms/step - loss: 4260.2598 - mse: 4260.2598 - mean_absolute_error: 61.5739 - r2_func_tf: -7.3291 - rmse_func_tf: 64.1885 - bias_func_tf: -60.4230 - sdep_func_tf: 21.5200 - val_loss: 4317.4336 - val_mse: 4317.4336 - val_mean_absolute_error: 63.3660 - val_r2_func_tf: -12.8690 - val_rmse_func_tf: 65.7072 - val_bias_func_tf: -63.3660 - val_sdep_func_tf: 17.3835
# Epoch 3/100
# 3/3 [==============================] - 0s 33ms/step - loss: 2754.5007 - mse: 2754.5007 - mean_absolute_error: 48.5401 - r2_func_tf: -3.7367 - rmse_func_tf: 48.1327 - bias_func_tf: -44.7220 - sdep_func_tf: 17.7267 - val_loss: 4040.3079 - val_mse: 4040.3079 - val_mean_absolute_error: 61.2581 - val_r2_func_tf: -11.9788 - val_rmse_func_tf: 63.5634 - val_bias_func_tf: -61.2581 - val_sdep_func_tf: 16.9631
# Epoch 4/100
# 3/3 [==============================] - 0s 34ms/step - loss: 914.4700 - mse: 914.4700 - mean_absolute_error: 25.5472 - r2_func_tf: -0.6804 - rmse_func_tf: 28.8796 - bias_func_tf: -22.3472 - sdep_func_tf: 17.7944 - val_loss: 3544.6174 - val_mse: 3544.6174 - val_mean_absolute_error: 57.2306 - val_r2_func_tf: -10.3865 - val_rmse_func_tf: 59.5367 - val_bias_func_tf: -57.2306 - val_sdep_func_tf: 16.4095
# Epoch 5/100
# 3/3 [==============================] - 0s 34ms/step - loss: 432.6678 - mse: 432.6678 - mean_absolute_error: 15.7624 - r2_func_tf: 0.0768 - rmse_func_tf: 21.3035 - bias_func_tf: 11.4621 - sdep_func_tf: 16.6128 - val_loss: 3099.2893 - val_mse: 3099.2893 - val_mean_absolute_error: 53.6194 - val_r2_func_tf: -8.9560 - val_rmse_func_tf: 55.6713 - val_bias_func_tf: -53.6194 - val_sdep_func_tf: 14.9749
# Epoch 6/100
# 3/3 [==============================] - 0s 32ms/step - loss: 617.9122 - mse: 617.9122 - mean_absolute_error: 18.5301 - r2_func_tf: -0.4050 - rmse_func_tf: 24.4377 - bias_func_tf: 14.3850 - sdep_func_tf: 18.6379 - val_loss: 3058.6797 - val_mse: 3058.6797 - val_mean_absolute_error: 53.4750 - val_r2_func_tf: -8.8255 - val_rmse_func_tf: 55.3053 - val_bias_func_tf: -53.4750 - val_sdep_func_tf: 14.1104
# Epoch 7/100
# 3/3 [==============================] - 0s 42ms/step - loss: 315.4278 - mse: 315.4278 - mean_absolute_error: 12.3526 - r2_func_tf: 0.4288 - rmse_func_tf: 16.6535 - bias_func_tf: -1.6481 - sdep_func_tf: 14.4505 - val_loss: 3107.6807 - val_mse: 3107.6807 - val_mean_absolute_error: 53.8667 - val_r2_func_tf: -8.9829 - val_rmse_func_tf: 55.7466 - val_bias_func_tf: -53.8667 - val_sdep_func_tf: 14.3548
# Epoch 8/100
# 3/3 [==============================] - 0s 33ms/step - loss: 209.9799 - mse: 209.9799 - mean_absolute_error: 12.2117 - r2_func_tf: 0.4893 - rmse_func_tf: 14.9893 - bias_func_tf: -8.0960 - sdep_func_tf: 12.5342 - val_loss: 3070.7700 - val_mse: 3070.7700 - val_mean_absolute_error: 53.3848 - val_r2_func_tf: -8.8643 - val_rmse_func_tf: 55.4145 - val_bias_func_tf: -53.3848 - val_sdep_func_tf: 14.8606
# Epoch 9/100
# 3/3 [==============================] - 0s 34ms/step - loss: 186.7600 - mse: 186.7600 - mean_absolute_error: 11.2325 - r2_func_tf: 0.3095 - rmse_func_tf: 13.5569 - bias_func_tf: -3.7105 - sdep_func_tf: 9.8666 - val_loss: 2962.8042 - val_mse: 2962.8042 - val_mean_absolute_error: 52.2415 - val_r2_func_tf: -8.5175 - val_rmse_func_tf: 54.4316 - val_bias_func_tf: -52.2415 - val_sdep_func_tf: 15.2851
# Epoch 10/100
# 3/3 [==============================] - 0s 34ms/step - loss: 175.1414 - mse: 175.1414 - mean_absolute_error: 10.3628 - r2_func_tf: 0.6148 - rmse_func_tf: 14.5117 - bias_func_tf: -8.8679 - sdep_func_tf: 11.3442 - val_loss: 2821.1323 - val_mse: 2821.1323 - val_mean_absolute_error: 50.7795 - val_r2_func_tf: -8.0624 - val_rmse_func_tf: 53.1143 - val_bias_func_tf: -50.7795 - val_sdep_func_tf: 15.5749
# Epoch 11/100
# 3/3 [==============================] - 0s 31ms/step - loss: 183.6451 - mse: 183.6451 - mean_absolute_error: 11.0597 - r2_func_tf: -0.5312 - rmse_func_tf: 13.9163 - bias_func_tf: 0.4328 - sdep_func_tf: 10.0111 - val_loss: 2633.1140 - val_mse: 2633.1140 - val_mean_absolute_error: 48.8688 - val_r2_func_tf: -7.4584 - val_rmse_func_tf: 51.3139 - val_bias_func_tf: -48.8688 - val_sdep_func_tf: 15.6510
# Epoch 12/100
# 3/3 [==============================] - 0s 33ms/step - loss: 98.4134 - mse: 98.4134 - mean_absolute_error: 7.7754 - r2_func_tf: 0.8368 - rmse_func_tf: 8.9626 - bias_func_tf: -0.5215 - sdep_func_tf: 8.5079 - val_loss: 2502.8271 - val_mse: 2502.8271 - val_mean_absolute_error: 47.5071 - val_r2_func_tf: -7.0399 - val_rmse_func_tf: 50.0283 - val_bias_func_tf: -47.5071 - val_sdep_func_tf: 15.6813
# Epoch 13/100
# 3/3 [==============================] - 0s 31ms/step - loss: 93.2264 - mse: 93.2264 - mean_absolute_error: 8.1142 - r2_func_tf: 0.8178 - rmse_func_tf: 9.2476 - bias_func_tf: 0.6940 - sdep_func_tf: 9.0260 - val_loss: 2391.9019 - val_mse: 2391.9019 - val_mean_absolute_error: 46.3362 - val_r2_func_tf: -6.6836 - val_rmse_func_tf: 48.9071 - val_bias_func_tf: -46.3362 - val_sdep_func_tf: 15.6479
# Epoch 14/100
# 3/3 [==============================] - 0s 34ms/step - loss: 99.9304 - mse: 99.9304 - mean_absolute_error: 8.1297 - r2_func_tf: 0.8112 - rmse_func_tf: 9.9000 - bias_func_tf: -0.4526 - sdep_func_tf: 9.6597 - val_loss: 2301.8237 - val_mse: 2301.8237 - val_mean_absolute_error: 45.3745 - val_r2_func_tf: -6.3942 - val_rmse_func_tf: 47.9773 - val_bias_func_tf: -45.3745 - val_sdep_func_tf: 15.5878
# Epoch 15/100
# 3/3 [==============================] - 0s 30ms/step - loss: 137.4150 - mse: 137.4150 - mean_absolute_error: 8.2734 - r2_func_tf: -0.7122 - rmse_func_tf: 13.3579 - bias_func_tf: 5.1719 - sdep_func_tf: 10.4821 - val_loss: 2236.7605 - val_mse: 2236.7605 - val_mean_absolute_error: 44.6762 - val_r2_func_tf: -6.1852 - val_rmse_func_tf: 47.2944 - val_bias_func_tf: -44.6762 - val_sdep_func_tf: 15.5177
# Epoch 16/100
# 3/3 [==============================] - 0s 30ms/step - loss: 73.7699 - mse: 73.7699 - mean_absolute_error: 6.5468 - r2_func_tf: 0.8527 - rmse_func_tf: 9.5719 - bias_func_tf: -2.9246 - sdep_func_tf: 8.8910 - val_loss: 2224.7861 - val_mse: 2224.7861 - val_mean_absolute_error: 44.5306 - val_r2_func_tf: -6.1468 - val_rmse_func_tf: 47.1676 - val_bias_func_tf: -44.5306 - val_sdep_func_tf: 15.5504
# Epoch 17/100
# 3/3 [==============================] - 0s 31ms/step - loss: 69.6170 - mse: 69.6170 - mean_absolute_error: 6.4828 - r2_func_tf: 0.8548 - rmse_func_tf: 9.0340 - bias_func_tf: -2.3999 - sdep_func_tf: 8.5305 - val_loss: 2171.7095 - val_mse: 2171.7095 - val_mean_absolute_error: 43.9350 - val_r2_func_tf: -5.9763 - val_rmse_func_tf: 46.6016 - val_bias_func_tf: -43.9350 - val_sdep_func_tf: 15.5379
# Epoch 18/100
# 3/3 [==============================] - 0s 31ms/step - loss: 123.1004 - mse: 123.1004 - mean_absolute_error: 8.0964 - r2_func_tf: 0.6554 - rmse_func_tf: 10.5507 - bias_func_tf: -2.1866 - sdep_func_tf: 10.0652 - val_loss: 2107.4463 - val_mse: 2107.4463 - val_mean_absolute_error: 43.1983 - val_r2_func_tf: -5.7698 - val_rmse_func_tf: 45.9069 - val_bias_func_tf: -43.1983 - val_sdep_func_tf: 15.5354
# Epoch 19/100
# 3/3 [==============================] - 0s 32ms/step - loss: 67.5483 - mse: 67.5483 - mean_absolute_error: 6.5127 - r2_func_tf: 0.8535 - rmse_func_tf: 7.8023 - bias_func_tf: -1.1323 - sdep_func_tf: 7.5812 - val_loss: 2036.3165 - val_mse: 2036.3165 - val_mean_absolute_error: 42.3681 - val_r2_func_tf: -5.5413 - val_rmse_func_tf: 45.1256 - val_bias_func_tf: -42.3681 - val_sdep_func_tf: 15.5326
# Epoch 20/100
# 3/3 [==============================] - 0s 33ms/step - loss: 54.4224 - mse: 54.4224 - mean_absolute_error: 5.8697 - r2_func_tf: 0.8900 - rmse_func_tf: 7.8121 - bias_func_tf: -1.1604 - sdep_func_tf: 7.6120 - val_loss: 1967.5933 - val_mse: 1967.5933 - val_mean_absolute_error: 41.5462 - val_r2_func_tf: -5.3206 - val_rmse_func_tf: 44.3576 - val_bias_func_tf: -41.5462 - val_sdep_func_tf: 15.5404
# Epoch 21/100
# 3/3 [==============================] - 0s 35ms/step - loss: 86.6930 - mse: 86.6930 - mean_absolute_error: 7.0307 - r2_func_tf: 0.8050 - rmse_func_tf: 10.3659 - bias_func_tf: -1.8595 - sdep_func_tf: 9.2023 - val_loss: 1899.7003 - val_mse: 1899.7003 - val_mean_absolute_error: 40.7188 - val_r2_func_tf: -5.1025 - val_rmse_func_tf: 43.5856 - val_bias_func_tf: -40.7188 - val_sdep_func_tf: 15.5461
# Epoch 22/100
# 3/3 [==============================] - 0s 31ms/step - loss: 53.3049 - mse: 53.3049 - mean_absolute_error: 5.8916 - r2_func_tf: 0.8887 - rmse_func_tf: 7.2454 - bias_func_tf: 0.7547 - sdep_func_tf: 7.1282 - val_loss: 1834.9690 - val_mse: 1834.9690 - val_mean_absolute_error: 39.9178 - val_r2_func_tf: -4.8945 - val_rmse_func_tf: 42.8365 - val_bias_func_tf: -39.9178 - val_sdep_func_tf: 15.5414
# Epoch 23/100
# 3/3 [==============================] - 0s 31ms/step - loss: 40.7748 - mse: 40.7748 - mean_absolute_error: 5.1718 - r2_func_tf: 0.9284 - rmse_func_tf: 5.9455 - bias_func_tf: 1.1940 - sdep_func_tf: 5.7513 - val_loss: 1790.0911 - val_mse: 1790.0911 - val_mean_absolute_error: 39.3412 - val_r2_func_tf: -4.7504 - val_rmse_func_tf: 42.3095 - val_bias_func_tf: -39.3412 - val_sdep_func_tf: 15.5680
# Epoch 24/100
# 3/3 [==============================] - 0s 31ms/step - loss: 55.6509 - mse: 55.6509 - mean_absolute_error: 5.8532 - r2_func_tf: 0.8215 - rmse_func_tf: 8.1786 - bias_func_tf: 1.0012 - sdep_func_tf: 7.9493 - val_loss: 1769.9766 - val_mse: 1769.9766 - val_mean_absolute_error: 39.0645 - val_r2_func_tf: -4.6858 - val_rmse_func_tf: 42.0711 - val_bias_func_tf: -39.0645 - val_sdep_func_tf: 15.6185
# Epoch 25/100
# 3/3 [==============================] - 0s 31ms/step - loss: 40.5498 - mse: 40.5498 - mean_absolute_error: 4.9836 - r2_func_tf: 0.9110 - rmse_func_tf: 6.8495 - bias_func_tf: 1.5079 - sdep_func_tf: 6.2086 - val_loss: 1754.0726 - val_mse: 1754.0726 - val_mean_absolute_error: 38.8318 - val_r2_func_tf: -4.6347 - val_rmse_func_tf: 41.8816 - val_bias_func_tf: -38.8318 - val_sdep_func_tf: 15.6897
# Epoch 26/100
# 3/3 [==============================] - 0s 31ms/step - loss: 40.4794 - mse: 40.4794 - mean_absolute_error: 5.0085 - r2_func_tf: 0.8997 - rmse_func_tf: 6.5405 - bias_func_tf: -0.5924 - sdep_func_tf: 6.4960 - val_loss: 1744.8583 - val_mse: 1744.8583 - val_mean_absolute_error: 38.6894 - val_r2_func_tf: -4.6051 - val_rmse_func_tf: 41.7715 - val_bias_func_tf: -38.6894 - val_sdep_func_tf: 15.7477
# Epoch 27/100
# 3/3 [==============================] - 0s 30ms/step - loss: 54.7765 - mse: 54.7765 - mean_absolute_error: 5.6433 - r2_func_tf: 0.8891 - rmse_func_tf: 7.1679 - bias_func_tf: -1.2364 - sdep_func_tf: 6.9048 - val_loss: 1721.8094 - val_mse: 1721.8094 - val_mean_absolute_error: 38.3698 - val_r2_func_tf: -4.5310 - val_rmse_func_tf: 41.4947 - val_bias_func_tf: -38.3698 - val_sdep_func_tf: 15.7976
# Epoch 28/100
# 3/3 [==============================] - 0s 32ms/step - loss: 98.7159 - mse: 98.7159 - mean_absolute_error: 7.2886 - r2_func_tf: -1.9306 - rmse_func_tf: 11.4750 - bias_func_tf: 4.4246 - sdep_func_tf: 6.9033 - val_loss: 1701.9556 - val_mse: 1701.9556 - val_mean_absolute_error: 38.0945 - val_r2_func_tf: -4.4672 - val_rmse_func_tf: 41.2548 - val_bias_func_tf: -38.0945 - val_sdep_func_tf: 15.8355
# Epoch 29/100
# 3/3 [==============================] - 0s 29ms/step - loss: 103.5287 - mse: 103.5287 - mean_absolute_error: 6.9267 - r2_func_tf: -4.5886 - rmse_func_tf: 11.7145 - bias_func_tf: 3.5527 - sdep_func_tf: 8.8054 - val_loss: 1722.5547 - val_mse: 1722.5547 - val_mean_absolute_error: 38.3391 - val_r2_func_tf: -4.5334 - val_rmse_func_tf: 41.5037 - val_bias_func_tf: -38.3391 - val_sdep_func_tf: 15.8957
# Epoch 30/100
# 3/3 [==============================] - 0s 29ms/step - loss: 60.1333 - mse: 60.1333 - mean_absolute_error: 6.7057 - r2_func_tf: 0.8734 - rmse_func_tf: 7.8062 - bias_func_tf: -4.3263 - sdep_func_tf: 6.4436 - val_loss: 1746.8394 - val_mse: 1746.8394 - val_mean_absolute_error: 38.6243 - val_r2_func_tf: -4.6114 - val_rmse_func_tf: 41.7952 - val_bias_func_tf: -38.6243 - val_sdep_func_tf: 15.9688
# Epoch 31/100
# 3/3 [==============================] - 0s 28ms/step - loss: 73.3042 - mse: 73.3042 - mean_absolute_error: 6.9804 - r2_func_tf: 0.7968 - rmse_func_tf: 8.9907 - bias_func_tf: -3.9107 - sdep_func_tf: 7.4524 - val_loss: 1719.2063 - val_mse: 1719.2063 - val_mean_absolute_error: 38.2470 - val_r2_func_tf: -4.5227 - val_rmse_func_tf: 41.4633 - val_bias_func_tf: -38.2470 - val_sdep_func_tf: 16.0117
# Epoch 32/100
# 3/3 [==============================] - 0s 30ms/step - loss: 83.5961 - mse: 83.5961 - mean_absolute_error: 7.1327 - r2_func_tf: -0.3956 - rmse_func_tf: 10.0993 - bias_func_tf: -1.1366 - sdep_func_tf: 8.4492 - val_loss: 1670.6049 - val_mse: 1670.6049 - val_mean_absolute_error: 37.5964 - val_r2_func_tf: -4.3665 - val_rmse_func_tf: 40.8730 - val_bias_func_tf: -37.5964 - val_sdep_func_tf: 16.0348
# Epoch 33/100
# 3/3 [==============================] - 0s 33ms/step - loss: 150.6413 - mse: 150.6413 - mean_absolute_error: 8.2047 - r2_func_tf: 0.5435 - rmse_func_tf: 12.8962 - bias_func_tf: -4.3789 - sdep_func_tf: 11.4477 - val_loss: 1622.4041 - val_mse: 1622.4041 - val_mean_absolute_error: 36.9279 - val_r2_func_tf: -4.2117 - val_rmse_func_tf: 40.2791 - val_bias_func_tf: -36.9279 - val_sdep_func_tf: 16.0853
# Epoch 34/100
# 3/3 [==============================] - 0s 32ms/step - loss: 83.1836 - mse: 83.1836 - mean_absolute_error: 6.7495 - r2_func_tf: -0.2509 - rmse_func_tf: 10.3177 - bias_func_tf: 2.0918 - sdep_func_tf: 8.0419 - val_loss: 1558.3330 - val_mse: 1558.3330 - val_mean_absolute_error: 36.0578 - val_r2_func_tf: -4.0059 - val_rmse_func_tf: 39.4757 - val_bias_func_tf: -36.0578 - val_sdep_func_tf: 16.0676
# Epoch 35/100
# 3/3 [==============================] - 0s 30ms/step - loss: 63.7652 - mse: 63.7652 - mean_absolute_error: 6.4401 - r2_func_tf: 0.8893 - rmse_func_tf: 7.3310 - bias_func_tf: -0.4615 - sdep_func_tf: 7.2881 - val_loss: 1529.6091 - val_mse: 1529.6091 - val_mean_absolute_error: 35.6488 - val_r2_func_tf: -3.9136 - val_rmse_func_tf: 39.1102 - val_bias_func_tf: -35.6488 - val_sdep_func_tf: 16.0864
# Epoch 36/100
# 3/3 [==============================] - 0s 31ms/step - loss: 39.3250 - mse: 39.3250 - mean_absolute_error: 4.9658 - r2_func_tf: 0.9125 - rmse_func_tf: 6.3992 - bias_func_tf: -0.0401 - sdep_func_tf: 6.3494 - val_loss: 1500.4668 - val_mse: 1500.4668 - val_mean_absolute_error: 35.2472 - val_r2_func_tf: -3.8200 - val_rmse_func_tf: 38.7359 - val_bias_func_tf: -35.2472 - val_sdep_func_tf: 16.0655
# Epoch 37/100
# 3/3 [==============================] - 0s 30ms/step - loss: 36.5674 - mse: 36.5674 - mean_absolute_error: 5.0262 - r2_func_tf: 0.9320 - rmse_func_tf: 5.7840 - bias_func_tf: 0.3552 - sdep_func_tf: 5.7207 - val_loss: 1474.1136 - val_mse: 1474.1136 - val_mean_absolute_error: 34.8923 - val_r2_func_tf: -3.7353 - val_rmse_func_tf: 38.3942 - val_bias_func_tf: -34.8923 - val_sdep_func_tf: 16.0201
# Epoch 38/100
# 3/3 [==============================] - 0s 30ms/step - loss: 78.5463 - mse: 78.5463 - mean_absolute_error: 6.7404 - r2_func_tf: 0.8324 - rmse_func_tf: 8.4290 - bias_func_tf: -0.4781 - sdep_func_tf: 7.6222 - val_loss: 1456.4862 - val_mse: 1456.4862 - val_mean_absolute_error: 34.6579 - val_r2_func_tf: -3.6787 - val_rmse_func_tf: 38.1639 - val_bias_func_tf: -34.6579 - val_sdep_func_tf: 15.9785
# Epoch 39/100
# 3/3 [==============================] - 0s 31ms/step - loss: 68.0793 - mse: 68.0793 - mean_absolute_error: 6.0991 - r2_func_tf: 0.8581 - rmse_func_tf: 7.7337 - bias_func_tf: 0.3113 - sdep_func_tf: 7.3623 - val_loss: 1432.7769 - val_mse: 1432.7769 - val_mean_absolute_error: 34.3459 - val_r2_func_tf: -3.6026 - val_rmse_func_tf: 37.8520 - val_bias_func_tf: -34.3459 - val_sdep_func_tf: 15.9103
# Epoch 40/100
# 3/3 [==============================] - 0s 30ms/step - loss: 37.4743 - mse: 37.4743 - mean_absolute_error: 4.6834 - r2_func_tf: 0.9238 - rmse_func_tf: 6.3332 - bias_func_tf: -0.6591 - sdep_func_tf: 5.9643 - val_loss: 1413.2667 - val_mse: 1413.2667 - val_mean_absolute_error: 34.0875 - val_r2_func_tf: -3.5399 - val_rmse_func_tf: 37.5934 - val_bias_func_tf: -34.0875 - val_sdep_func_tf: 15.8526
# Epoch 41/100
# 3/3 [==============================] - 0s 29ms/step - loss: 178.4549 - mse: 178.4549 - mean_absolute_error: 9.3248 - r2_func_tf: -1.6389 - rmse_func_tf: 13.6522 - bias_func_tf: 3.8090 - sdep_func_tf: 11.6754 - val_loss: 1404.8489 - val_mse: 1404.8489 - val_mean_absolute_error: 33.9805 - val_r2_func_tf: -3.5128 - val_rmse_func_tf: 37.4813 - val_bias_func_tf: -33.9805 - val_sdep_func_tf: 15.8168
# Epoch 42/100
# 3/3 [==============================] - 0s 31ms/step - loss: 37.1491 - mse: 37.1491 - mean_absolute_error: 4.5822 - r2_func_tf: 0.8551 - rmse_func_tf: 6.8807 - bias_func_tf: -0.5136 - sdep_func_tf: 6.8411 - val_loss: 1413.7295 - val_mse: 1413.7295 - val_mean_absolute_error: 34.1085 - val_r2_func_tf: -3.5414 - val_rmse_func_tf: 37.5996 - val_bias_func_tf: -34.1085 - val_sdep_func_tf: 15.8221
# Epoch 43/100
# 3/3 [==============================] - 0s 29ms/step - loss: 32.8707 - mse: 32.8707 - mean_absolute_error: 4.5087 - r2_func_tf: 0.8973 - rmse_func_tf: 6.4146 - bias_func_tf: -1.1800 - sdep_func_tf: 6.2766 - val_loss: 1409.4968 - val_mse: 1409.4968 - val_mean_absolute_error: 34.0400 - val_r2_func_tf: -3.5278 - val_rmse_func_tf: 37.5433 - val_bias_func_tf: -34.0400 - val_sdep_func_tf: 15.8359
# Epoch 44/100
# 3/3 [==============================] - 0s 30ms/step - loss: 31.1367 - mse: 31.1367 - mean_absolute_error: 4.4755 - r2_func_tf: 0.9440 - rmse_func_tf: 5.4881 - bias_func_tf: -1.4250 - sdep_func_tf: 5.2204 - val_loss: 1395.7726 - val_mse: 1395.7726 - val_mean_absolute_error: 33.8325 - val_r2_func_tf: -3.4837 - val_rmse_func_tf: 37.3600 - val_bias_func_tf: -33.8325 - val_sdep_func_tf: 15.8473
# Epoch 45/100
# 3/3 [==============================] - 0s 30ms/step - loss: 44.5479 - mse: 44.5479 - mean_absolute_error: 5.0828 - r2_func_tf: 0.8329 - rmse_func_tf: 7.2817 - bias_func_tf: 0.6976 - sdep_func_tf: 6.4920 - val_loss: 1373.3132 - val_mse: 1373.3132 - val_mean_absolute_error: 33.5003 - val_r2_func_tf: -3.4115 - val_rmse_func_tf: 37.0582 - val_bias_func_tf: -33.5003 - val_sdep_func_tf: 15.8443
# Epoch 46/100
# 3/3 [==============================] - 0s 32ms/step - loss: 27.9320 - mse: 27.9320 - mean_absolute_error: 4.1310 - r2_func_tf: 0.9352 - rmse_func_tf: 5.4467 - bias_func_tf: -0.3506 - sdep_func_tf: 5.3222 - val_loss: 1361.1792 - val_mse: 1361.1792 - val_mean_absolute_error: 33.3150 - val_r2_func_tf: -3.3726 - val_rmse_func_tf: 36.8942 - val_bias_func_tf: -33.3150 - val_sdep_func_tf: 15.8521
# Epoch 47/100
# 3/3 [==============================] - 0s 32ms/step - loss: 28.3748 - mse: 28.3748 - mean_absolute_error: 4.3277 - r2_func_tf: 0.9333 - rmse_func_tf: 5.6632 - bias_func_tf: 0.1160 - sdep_func_tf: 5.2392 - val_loss: 1348.2703 - val_mse: 1348.2703 - val_mean_absolute_error: 33.1196 - val_r2_func_tf: -3.3311 - val_rmse_func_tf: 36.7188 - val_bias_func_tf: -33.1196 - val_sdep_func_tf: 15.8544
# Epoch 48/100
# 3/3 [==============================] - 0s 31ms/step - loss: 27.5403 - mse: 27.5403 - mean_absolute_error: 4.2506 - r2_func_tf: 0.9412 - rmse_func_tf: 5.4246 - bias_func_tf: -0.1658 - sdep_func_tf: 5.2816 - val_loss: 1336.8157 - val_mse: 1336.8157 - val_mean_absolute_error: 32.9505 - val_r2_func_tf: -3.2943 - val_rmse_func_tf: 36.5625 - val_bias_func_tf: -32.9505 - val_sdep_func_tf: 15.8456
# Epoch 49/100
# 3/3 [==============================] - 0s 30ms/step - loss: 36.0419 - mse: 36.0419 - mean_absolute_error: 5.0050 - r2_func_tf: 0.9222 - rmse_func_tf: 6.2012 - bias_func_tf: -1.4803 - sdep_func_tf: 5.7687 - val_loss: 1322.0219 - val_mse: 1322.0219 - val_mean_absolute_error: 32.7308 - val_r2_func_tf: -3.2468 - val_rmse_func_tf: 36.3596 - val_bias_func_tf: -32.7308 - val_sdep_func_tf: 15.8340
# Epoch 50/100
# 3/3 [==============================] - 0s 30ms/step - loss: 41.9354 - mse: 41.9354 - mean_absolute_error: 5.0783 - r2_func_tf: 0.9057 - rmse_func_tf: 7.2836 - bias_func_tf: -0.7360 - sdep_func_tf: 7.0484 - val_loss: 1303.3805 - val_mse: 1303.3805 - val_mean_absolute_error: 32.4591 - val_r2_func_tf: -3.1869 - val_rmse_func_tf: 36.1024 - val_bias_func_tf: -32.4591 - val_sdep_func_tf: 15.8048
# Epoch 51/100
# 3/3 [==============================] - 0s 30ms/step - loss: 46.1251 - mse: 46.1251 - mean_absolute_error: 5.4944 - r2_func_tf: 0.9074 - rmse_func_tf: 6.7487 - bias_func_tf: 0.4242 - sdep_func_tf: 6.2487 - val_loss: 1281.8066 - val_mse: 1281.8066 - val_mean_absolute_error: 32.1508 - val_r2_func_tf: -3.1176 - val_rmse_func_tf: 35.8023 - val_bias_func_tf: -32.1508 - val_sdep_func_tf: 15.7521
# Epoch 52/100
# 3/3 [==============================] - 0s 29ms/step - loss: 26.8055 - mse: 26.8055 - mean_absolute_error: 4.1753 - r2_func_tf: 0.9382 - rmse_func_tf: 5.6549 - bias_func_tf: -0.3019 - sdep_func_tf: 5.5801 - val_loss: 1270.2163 - val_mse: 1270.2163 - val_mean_absolute_error: 31.9869 - val_r2_func_tf: -3.0804 - val_rmse_func_tf: 35.6401 - val_bias_func_tf: -31.9869 - val_sdep_func_tf: 15.7180
# Epoch 53/100
# 3/3 [==============================] - 0s 31ms/step - loss: 56.9360 - mse: 56.9360 - mean_absolute_error: 5.5517 - r2_func_tf: 0.8708 - rmse_func_tf: 8.0324 - bias_func_tf: -1.2581 - sdep_func_tf: 7.7779 - val_loss: 1255.3757 - val_mse: 1255.3757 - val_mean_absolute_error: 31.7684 - val_r2_func_tf: -3.0327 - val_rmse_func_tf: 35.4313 - val_bias_func_tf: -31.7684 - val_sdep_func_tf: 15.6890
# Epoch 54/100
# 3/3 [==============================] - 0s 53ms/step - loss: 35.6045 - mse: 35.6045 - mean_absolute_error: 4.8633 - r2_func_tf: 0.9363 - rmse_func_tf: 5.4458 - bias_func_tf: 0.0931 - sdep_func_tf: 5.2645 - val_loss: 1238.2612 - val_mse: 1238.2612 - val_mean_absolute_error: 31.5187 - val_r2_func_tf: -2.9777 - val_rmse_func_tf: 35.1889 - val_bias_func_tf: -31.5187 - val_sdep_func_tf: 15.6471
# Epoch 55/100
# 3/3 [==============================] - 0s 30ms/step - loss: 45.8399 - mse: 45.8399 - mean_absolute_error: 5.4445 - r2_func_tf: 0.8900 - rmse_func_tf: 7.6533 - bias_func_tf: -1.7338 - sdep_func_tf: 6.4096 - val_loss: 1222.2905 - val_mse: 1222.2905 - val_mean_absolute_error: 31.2833 - val_r2_func_tf: -2.9264 - val_rmse_func_tf: 34.9613 - val_bias_func_tf: -31.2833 - val_sdep_func_tf: 15.6091
# Epoch 56/100
# 3/3 [==============================] - 0s 30ms/step - loss: 41.6976 - mse: 41.6976 - mean_absolute_error: 4.8264 - r2_func_tf: 0.9044 - rmse_func_tf: 6.5291 - bias_func_tf: 0.2008 - sdep_func_tf: 6.1519 - val_loss: 1200.4547 - val_mse: 1200.4547 - val_mean_absolute_error: 30.9586 - val_r2_func_tf: -2.8563 - val_rmse_func_tf: 34.6476 - val_bias_func_tf: -30.9586 - val_sdep_func_tf: 15.5570
# Epoch 57/100
# 3/3 [==============================] - 0s 30ms/step - loss: 34.1786 - mse: 34.1786 - mean_absolute_error: 4.6516 - r2_func_tf: 0.8981 - rmse_func_tf: 6.5513 - bias_func_tf: 1.3973 - sdep_func_tf: 6.4002 - val_loss: 1191.4680 - val_mse: 1191.4680 - val_mean_absolute_error: 30.8348 - val_r2_func_tf: -2.8274 - val_rmse_func_tf: 34.5176 - val_bias_func_tf: -30.8348 - val_sdep_func_tf: 15.5140
# Epoch 58/100
# 3/3 [==============================] - 0s 29ms/step - loss: 66.9669 - mse: 66.9669 - mean_absolute_error: 6.1400 - r2_func_tf: 0.1000 - rmse_func_tf: 9.4292 - bias_func_tf: 5.1096 - sdep_func_tf: 7.1025 - val_loss: 1201.5560 - val_mse: 1201.5560 - val_mean_absolute_error: 31.0080 - val_r2_func_tf: -2.8598 - val_rmse_func_tf: 34.6635 - val_bias_func_tf: -31.0080 - val_sdep_func_tf: 15.4938
# Epoch 59/100
# 3/3 [==============================] - 0s 28ms/step - loss: 83.7668 - mse: 83.7668 - mean_absolute_error: 6.1351 - r2_func_tf: 0.7638 - rmse_func_tf: 8.4454 - bias_func_tf: 0.9701 - sdep_func_tf: 8.0011 - val_loss: 1230.3799 - val_mse: 1230.3799 - val_mean_absolute_error: 31.4601 - val_r2_func_tf: -2.9524 - val_rmse_func_tf: 35.0768 - val_bias_func_tf: -31.4601 - val_sdep_func_tf: 15.5127
# Epoch 60/100
# 3/3 [==============================] - 0s 30ms/step - loss: 30.8355 - mse: 30.8355 - mean_absolute_error: 4.5276 - r2_func_tf: 0.9275 - rmse_func_tf: 5.7886 - bias_func_tf: -0.6863 - sdep_func_tf: 5.5882 - val_loss: 1255.5146 - val_mse: 1255.5146 - val_mean_absolute_error: 31.8389 - val_r2_func_tf: -3.0331 - val_rmse_func_tf: 35.4332 - val_bias_func_tf: -31.8389 - val_sdep_func_tf: 15.5499
# Epoch 61/100
# 3/3 [==============================] - 0s 29ms/step - loss: 44.7857 - mse: 44.7857 - mean_absolute_error: 5.0158 - r2_func_tf: 0.8881 - rmse_func_tf: 7.5392 - bias_func_tf: -3.3517 - sdep_func_tf: 6.3870 - val_loss: 1260.2238 - val_mse: 1260.2238 - val_mean_absolute_error: 31.8950 - val_r2_func_tf: -3.0483 - val_rmse_func_tf: 35.4996 - val_bias_func_tf: -31.8950 - val_sdep_func_tf: 15.5864
# Epoch 62/100
# 3/3 [==============================] - 0s 30ms/step - loss: 32.0410 - mse: 32.0410 - mean_absolute_error: 4.5357 - r2_func_tf: 0.8912 - rmse_func_tf: 6.1752 - bias_func_tf: -2.0290 - sdep_func_tf: 5.7411 - val_loss: 1241.5111 - val_mse: 1241.5111 - val_mean_absolute_error: 31.5945 - val_r2_func_tf: -2.9881 - val_rmse_func_tf: 35.2351 - val_bias_func_tf: -31.5945 - val_sdep_func_tf: 15.5980
# Epoch 63/100
# 3/3 [==============================] - 0s 30ms/step - loss: 79.8050 - mse: 79.8050 - mean_absolute_error: 6.5254 - r2_func_tf: -0.6144 - rmse_func_tf: 10.1780 - bias_func_tf: 3.5900 - sdep_func_tf: 7.1225 - val_loss: 1223.5889 - val_mse: 1223.5889 - val_mean_absolute_error: 31.3027 - val_r2_func_tf: -2.9306 - val_rmse_func_tf: 34.9798 - val_bias_func_tf: -31.3027 - val_sdep_func_tf: 15.6118
# Epoch 64/100
# 3/3 [==============================] - 0s 29ms/step - loss: 30.9575 - mse: 30.9575 - mean_absolute_error: 4.4455 - r2_func_tf: 0.9496 - rmse_func_tf: 4.8892 - bias_func_tf: -1.0594 - sdep_func_tf: 4.5864 - val_loss: 1223.1548 - val_mse: 1223.1548 - val_mean_absolute_error: 31.2849 - val_r2_func_tf: -2.9292 - val_rmse_func_tf: 34.9736 - val_bias_func_tf: -31.2849 - val_sdep_func_tf: 15.6337
# Epoch 65/100
# 3/3 [==============================] - 0s 29ms/step - loss: 26.6496 - mse: 26.6496 - mean_absolute_error: 4.0926 - r2_func_tf: 0.9371 - rmse_func_tf: 5.6238 - bias_func_tf: -2.1357 - sdep_func_tf: 4.7910 - val_loss: 1216.9702 - val_mse: 1216.9702 - val_mean_absolute_error: 31.1811 - val_r2_func_tf: -2.9093 - val_rmse_func_tf: 34.8851 - val_bias_func_tf: -31.1811 - val_sdep_func_tf: 15.6432
# Epoch 66/100
# 3/3 [==============================] - 0s 29ms/step - loss: 50.4318 - mse: 50.4318 - mean_absolute_error: 5.3118 - r2_func_tf: 0.7897 - rmse_func_tf: 7.4252 - bias_func_tf: 0.6302 - sdep_func_tf: 6.6001 - val_loss: 1198.1360 - val_mse: 1198.1360 - val_mean_absolute_error: 30.8921 - val_r2_func_tf: -2.8488 - val_rmse_func_tf: 34.6141 - val_bias_func_tf: -30.8921 - val_sdep_func_tf: 15.6145
# Epoch 67/100
# 3/3 [==============================] - 0s 31ms/step - loss: 79.7771 - mse: 79.7771 - mean_absolute_error: 6.4970 - r2_func_tf: 0.7659 - rmse_func_tf: 9.8972 - bias_func_tf: -1.6147 - sdep_func_tf: 9.4984 - val_loss: 1190.3318 - val_mse: 1190.3318 - val_mean_absolute_error: 30.7816 - val_r2_func_tf: -2.8237 - val_rmse_func_tf: 34.5012 - val_bias_func_tf: -30.7816 - val_sdep_func_tf: 15.5828
# Epoch 68/100
# 3/3 [==============================] - 0s 32ms/step - loss: 24.9600 - mse: 24.9600 - mean_absolute_error: 4.0353 - r2_func_tf: 0.9406 - rmse_func_tf: 5.2182 - bias_func_tf: 0.4806 - sdep_func_tf: 5.0191 - val_loss: 1179.6616 - val_mse: 1179.6616 - val_mean_absolute_error: 30.6421 - val_r2_func_tf: -2.7895 - val_rmse_func_tf: 34.3462 - val_bias_func_tf: -30.6421 - val_sdep_func_tf: 15.5153
# Epoch 69/100
# 3/3 [==============================] - 0s 30ms/step - loss: 28.8372 - mse: 28.8372 - mean_absolute_error: 4.2265 - r2_func_tf: 0.9264 - rmse_func_tf: 6.0505 - bias_func_tf: -0.2330 - sdep_func_tf: 6.0291 - val_loss: 1178.3322 - val_mse: 1178.3322 - val_mean_absolute_error: 30.6526 - val_r2_func_tf: -2.7852 - val_rmse_func_tf: 34.3268 - val_bias_func_tf: -30.6526 - val_sdep_func_tf: 15.4516
# Epoch 70/100
# 3/3 [==============================] - 0s 29ms/step - loss: 62.8764 - mse: 62.8764 - mean_absolute_error: 6.0273 - r2_func_tf: 0.8539 - rmse_func_tf: 8.6134 - bias_func_tf: -1.1420 - sdep_func_tf: 8.2960 - val_loss: 1180.9709 - val_mse: 1180.9709 - val_mean_absolute_error: 30.7304 - val_r2_func_tf: -2.7937 - val_rmse_func_tf: 34.3653 - val_bias_func_tf: -30.7304 - val_sdep_func_tf: 15.3823
# Epoch 71/100
# 3/3 [==============================] - 0s 30ms/step - loss: 41.5508 - mse: 41.5508 - mean_absolute_error: 4.7317 - r2_func_tf: 0.9098 - rmse_func_tf: 7.1966 - bias_func_tf: -0.9154 - sdep_func_tf: 6.7217 - val_loss: 1176.6130 - val_mse: 1176.6130 - val_mean_absolute_error: 30.6961 - val_r2_func_tf: -2.7797 - val_rmse_func_tf: 34.3018 - val_bias_func_tf: -30.6961 - val_sdep_func_tf: 15.3089
# Epoch 72/100
# 3/3 [==============================] - 0s 31ms/step - loss: 33.8281 - mse: 33.8281 - mean_absolute_error: 4.6387 - r2_func_tf: 0.9323 - rmse_func_tf: 5.7273 - bias_func_tf: -0.0478 - sdep_func_tf: 5.6742 - val_loss: 1167.1078 - val_mse: 1167.1078 - val_mean_absolute_error: 30.5754 - val_r2_func_tf: -2.7491 - val_rmse_func_tf: 34.1630 - val_bias_func_tf: -30.5754 - val_sdep_func_tf: 15.2399
# Epoch 73/100
# 3/3 [==============================] - 0s 31ms/step - loss: 39.0571 - mse: 39.0571 - mean_absolute_error: 4.7203 - r2_func_tf: 0.9217 - rmse_func_tf: 5.7871 - bias_func_tf: 0.2561 - sdep_func_tf: 5.6768 - val_loss: 1163.4871 - val_mse: 1163.4871 - val_mean_absolute_error: 30.5446 - val_r2_func_tf: -2.7375 - val_rmse_func_tf: 34.1099 - val_bias_func_tf: -30.5446 - val_sdep_func_tf: 15.1826
# Epoch 74/100
# 3/3 [==============================] - 0s 30ms/step - loss: 44.9468 - mse: 44.9468 - mean_absolute_error: 5.0787 - r2_func_tf: 0.6993 - rmse_func_tf: 7.6191 - bias_func_tf: 3.0277 - sdep_func_tf: 6.3340 - val_loss: 1166.7922 - val_mse: 1166.7922 - val_mean_absolute_error: 30.6253 - val_r2_func_tf: -2.7481 - val_rmse_func_tf: 34.1583 - val_bias_func_tf: -30.6253 - val_sdep_func_tf: 15.1290
# Epoch 75/100
# 3/3 [==============================] - 0s 29ms/step - loss: 57.2192 - mse: 57.2192 - mean_absolute_error: 5.5024 - r2_func_tf: 0.8688 - rmse_func_tf: 8.5817 - bias_func_tf: -1.1357 - sdep_func_tf: 8.1793 - val_loss: 1177.7747 - val_mse: 1177.7747 - val_mean_absolute_error: 30.8089 - val_r2_func_tf: -2.7834 - val_rmse_func_tf: 34.3187 - val_bias_func_tf: -30.8089 - val_sdep_func_tf: 15.1191
# Epoch 76/100
# 3/3 [==============================] - 0s 31ms/step - loss: 22.9807 - mse: 22.9807 - mean_absolute_error: 3.7920 - r2_func_tf: 0.9463 - rmse_func_tf: 4.9150 - bias_func_tf: 0.4665 - sdep_func_tf: 4.7295 - val_loss: 1183.3403 - val_mse: 1183.3403 - val_mean_absolute_error: 30.9158 - val_r2_func_tf: -2.8013 - val_rmse_func_tf: 34.3997 - val_bias_func_tf: -30.9158 - val_sdep_func_tf: 15.0848
# Epoch 77/100
# 3/3 [==============================] - 0s 30ms/step - loss: 49.3155 - mse: 49.3155 - mean_absolute_error: 5.5611 - r2_func_tf: 0.8826 - rmse_func_tf: 7.0352 - bias_func_tf: -0.2411 - sdep_func_tf: 6.9996 - val_loss: 1191.4421 - val_mse: 1191.4421 - val_mean_absolute_error: 31.0493 - val_r2_func_tf: -2.8273 - val_rmse_func_tf: 34.5173 - val_bias_func_tf: -31.0493 - val_sdep_func_tf: 15.0793
# Epoch 78/100
# 3/3 [==============================] - 0s 31ms/step - loss: 36.0645 - mse: 36.0645 - mean_absolute_error: 4.2831 - r2_func_tf: 0.8225 - rmse_func_tf: 6.7284 - bias_func_tf: 0.6983 - sdep_func_tf: 6.2729 - val_loss: 1199.0907 - val_mse: 1199.0907 - val_mean_absolute_error: 31.1706 - val_r2_func_tf: -2.8519 - val_rmse_func_tf: 34.6279 - val_bias_func_tf: -31.1706 - val_sdep_func_tf: 15.0827
# Epoch 79/100
# 3/3 [==============================] - 0s 30ms/step - loss: 127.4703 - mse: 127.4703 - mean_absolute_error: 6.8640 - r2_func_tf: 0.6204 - rmse_func_tf: 9.9341 - bias_func_tf: -0.2549 - sdep_func_tf: 9.6297 - val_loss: 1210.7993 - val_mse: 1210.7993 - val_mean_absolute_error: 31.3440 - val_r2_func_tf: -2.8895 - val_rmse_func_tf: 34.7965 - val_bias_func_tf: -31.3440 - val_sdep_func_tf: 15.1113
# Epoch 80/100
# 3/3 [==============================] - 0s 30ms/step - loss: 48.0196 - mse: 48.0196 - mean_absolute_error: 5.1044 - r2_func_tf: 0.4962 - rmse_func_tf: 7.6586 - bias_func_tf: 1.3399 - sdep_func_tf: 7.0031 - val_loss: 1219.5669 - val_mse: 1219.5669 - val_mean_absolute_error: 31.4823 - val_r2_func_tf: -2.9177 - val_rmse_func_tf: 34.9223 - val_bias_func_tf: -31.4823 - val_sdep_func_tf: 15.1140
# Epoch 81/100
# 3/3 [==============================] - 0s 29ms/step - loss: 34.7257 - mse: 34.7257 - mean_absolute_error: 4.2731 - r2_func_tf: 0.8525 - rmse_func_tf: 6.6948 - bias_func_tf: 0.1076 - sdep_func_tf: 6.2142 - val_loss: 1231.5020 - val_mse: 1231.5020 - val_mean_absolute_error: 31.6632 - val_r2_func_tf: -2.9560 - val_rmse_func_tf: 35.0928 - val_bias_func_tf: -31.6632 - val_sdep_func_tf: 15.1309
# Epoch 82/100
# 3/3 [==============================] - 0s 44ms/step - loss: 33.1844 - mse: 33.1844 - mean_absolute_error: 4.5664 - r2_func_tf: 0.9025 - rmse_func_tf: 6.2492 - bias_func_tf: -1.4468 - sdep_func_tf: 5.9614 - val_loss: 1241.3730 - val_mse: 1241.3730 - val_mean_absolute_error: 31.8100 - val_r2_func_tf: -2.9877 - val_rmse_func_tf: 35.2331 - val_bias_func_tf: -31.8100 - val_sdep_func_tf: 15.1491
# Epoch 83/100
# 3/3 [==============================] - 0s 29ms/step - loss: 35.3567 - mse: 35.3567 - mean_absolute_error: 4.8219 - r2_func_tf: 0.9153 - rmse_func_tf: 6.1827 - bias_func_tf: -1.0987 - sdep_func_tf: 5.8720 - val_loss: 1243.7898 - val_mse: 1243.7898 - val_mean_absolute_error: 31.8423 - val_r2_func_tf: -2.9955 - val_rmse_func_tf: 35.2674 - val_bias_func_tf: -31.8423 - val_sdep_func_tf: 15.1611
# Epoch 84/100
# 3/3 [==============================] - 0s 29ms/step - loss: 69.2884 - mse: 69.2884 - mean_absolute_error: 5.6532 - r2_func_tf: 0.0087 - rmse_func_tf: 9.5022 - bias_func_tf: 2.8525 - sdep_func_tf: 7.5711 - val_loss: 1252.8401 - val_mse: 1252.8401 - val_mean_absolute_error: 31.9925 - val_r2_func_tf: -3.0245 - val_rmse_func_tf: 35.3955 - val_bias_func_tf: -31.9925 - val_sdep_func_tf: 15.1434
# Epoch 85/100
# 3/3 [==============================] - 0s 29ms/step - loss: 96.8134 - mse: 96.8134 - mean_absolute_error: 6.6906 - r2_func_tf: -1.3897 - rmse_func_tf: 11.3339 - bias_func_tf: 4.9627 - sdep_func_tf: 7.6776 - val_loss: 1285.6270 - val_mse: 1285.6270 - val_mean_absolute_error: 32.5048 - val_r2_func_tf: -3.1299 - val_rmse_func_tf: 35.8556 - val_bias_func_tf: -32.5048 - val_sdep_func_tf: 15.1350
# Epoch 86/100
# 3/3 [==============================] - 0s 31ms/step - loss: 60.5550 - mse: 60.5550 - mean_absolute_error: 5.0223 - r2_func_tf: 0.8324 - rmse_func_tf: 8.9150 - bias_func_tf: -4.5966 - sdep_func_tf: 7.1581 - val_loss: 1325.6033 - val_mse: 1325.6033 - val_mean_absolute_error: 33.1080 - val_r2_func_tf: -3.2583 - val_rmse_func_tf: 36.4088 - val_bias_func_tf: -33.1080 - val_sdep_func_tf: 15.1481
# Epoch 87/100
# 3/3 [==============================] - 0s 30ms/step - loss: 52.5281 - mse: 52.5281 - mean_absolute_error: 5.2662 - r2_func_tf: 0.8667 - rmse_func_tf: 8.2373 - bias_func_tf: -4.2506 - sdep_func_tf: 6.6576 - val_loss: 1329.9397 - val_mse: 1329.9397 - val_mean_absolute_error: 33.1899 - val_r2_func_tf: -3.2722 - val_rmse_func_tf: 36.4683 - val_bias_func_tf: -33.1899 - val_sdep_func_tf: 15.1118
# Epoch 88/100
# 3/3 [==============================] - 0s 30ms/step - loss: 39.5621 - mse: 39.5621 - mean_absolute_error: 4.8385 - r2_func_tf: 0.9235 - rmse_func_tf: 6.1673 - bias_func_tf: -1.7220 - sdep_func_tf: 5.6289 - val_loss: 1318.6923 - val_mse: 1318.6923 - val_mean_absolute_error: 33.0488 - val_r2_func_tf: -3.2361 - val_rmse_func_tf: 36.3138 - val_bias_func_tf: -33.0488 - val_sdep_func_tf: 15.0488
# Epoch 89/100
# 3/3 [==============================] - 0s 29ms/step - loss: 118.3574 - mse: 118.3574 - mean_absolute_error: 7.1555 - r2_func_tf: 0.6156 - rmse_func_tf: 10.8216 - bias_func_tf: -1.2931 - sdep_func_tf: 10.6062 - val_loss: 1305.2119 - val_mse: 1305.2119 - val_mean_absolute_error: 32.8751 - val_r2_func_tf: -3.1928 - val_rmse_func_tf: 36.1277 - val_bias_func_tf: -32.8751 - val_sdep_func_tf: 14.9814
# Epoch 90/100
# 3/3 [==============================] - 0s 29ms/step - loss: 53.5656 - mse: 53.5656 - mean_absolute_error: 5.5753 - r2_func_tf: 0.3596 - rmse_func_tf: 8.2497 - bias_func_tf: 2.7827 - sdep_func_tf: 6.8121 - val_loss: 1300.4318 - val_mse: 1300.4318 - val_mean_absolute_error: 32.8418 - val_r2_func_tf: -3.1774 - val_rmse_func_tf: 36.0615 - val_bias_func_tf: -32.8418 - val_sdep_func_tf: 14.8946
# Epoch 91/100
# 3/3 [==============================] - 0s 29ms/step - loss: 26.8088 - mse: 26.8088 - mean_absolute_error: 4.1315 - r2_func_tf: 0.9485 - rmse_func_tf: 5.2377 - bias_func_tf: 0.0029 - sdep_func_tf: 5.1516 - val_loss: 1315.9561 - val_mse: 1315.9561 - val_mean_absolute_error: 33.0995 - val_r2_func_tf: -3.2273 - val_rmse_func_tf: 36.2761 - val_bias_func_tf: -33.0995 - val_sdep_func_tf: 14.8451
# Epoch 92/100
# 3/3 [==============================] - 0s 31ms/step - loss: 45.1483 - mse: 45.1483 - mean_absolute_error: 4.9809 - r2_func_tf: 0.8991 - rmse_func_tf: 7.2862 - bias_func_tf: -0.8500 - sdep_func_tf: 7.1707 - val_loss: 1328.2985 - val_mse: 1328.2985 - val_mean_absolute_error: 33.3114 - val_r2_func_tf: -3.2669 - val_rmse_func_tf: 36.4458 - val_bias_func_tf: -33.3114 - val_sdep_func_tf: 14.7869
# Epoch 93/100
# 1/3 [=========>....................] - ETA: 0s - loss: 44.5830 - mse: 44.5830 - mean_absolute_error: 5.6906 - r2_func_tf: 0.9338 - rmse_func_tf: 6.6771 - bias_func_tf: -1.0521 - sdep_func_tf: 6.5936Restoring model weights from the end of the best epoch: 73.
# 3/3 [==============================] - 0s 34ms/step - loss: 47.3105 - mse: 47.3105 - mean_absolute_error: 5.2422 - r2_func_tf: 0.6724 - rmse_func_tf: 7.6428 - bias_func_tf: 2.4327 - sdep_func_tf: 6.4249 - val_loss: 1341.7428 - val_mse: 1341.7428 - val_mean_absolute_error: 33.5496 - val_r2_func_tf: -3.3101 - val_rmse_func_tf: 36.6298 - val_bias_func_tf: -33.5496 - val_sdep_func_tf: 14.7025
# Epoch 93: early stopping
# 4/4 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 3ms/step
# dense1:  32
# dense2:  32
# dense3:  2
# Epoch 1/100
# 3/3 [==============================] - 2s 161ms/step - loss: 5137.9141 - mse: 5137.9141 - mean_absolute_error: 68.4021 - r2_func_tf: -11.3422 - rmse_func_tf: 75.6686 - bias_func_tf: -72.2082 - sdep_func_tf: 22.4353 - val_loss: 4954.9600 - val_mse: 4954.9600 - val_mean_absolute_error: 66.9320 - val_r2_func_tf: -inf - val_rmse_func_tf: 81.0300 - val_bias_func_tf: -79.3026 - val_sdep_func_tf: 10.8270
# Epoch 2/100
# 3/3 [==============================] - 0s 34ms/step - loss: 5090.3247 - mse: 5090.3247 - mean_absolute_error: 68.0640 - r2_func_tf: -10.3214 - rmse_func_tf: 73.9236 - bias_func_tf: -70.2778 - sdep_func_tf: 22.7243 - val_loss: 4951.6211 - val_mse: 4951.6211 - val_mean_absolute_error: 66.9070 - val_r2_func_tf: -inf - val_rmse_func_tf: 81.0057 - val_bias_func_tf: -79.2777 - val_sdep_func_tf: 10.8270
# Epoch 3/100
# 3/3 [==============================] - 0s 32ms/step - loss: 5087.0068 - mse: 5087.0068 - mean_absolute_error: 68.0397 - r2_func_tf: -14.6446 - rmse_func_tf: 76.8656 - bias_func_tf: -74.0099 - sdep_func_tf: 20.5573 - val_loss: 4948.6577 - val_mse: 4948.6577 - val_mean_absolute_error: 66.8849 - val_r2_func_tf: -inf - val_rmse_func_tf: 80.9841 - val_bias_func_tf: -79.2555 - val_sdep_func_tf: 10.8270
# Epoch 4/100
# 3/3 [==============================] - 0s 34ms/step - loss: 5084.0894 - mse: 5084.0894 - mean_absolute_error: 68.0181 - r2_func_tf: -12.7018 - rmse_func_tf: 71.3695 - bias_func_tf: -68.4267 - sdep_func_tf: 20.0855 - val_loss: 4945.9951 - val_mse: 4945.9951 - val_mean_absolute_error: 66.8650 - val_r2_func_tf: -inf - val_rmse_func_tf: 80.9647 - val_bias_func_tf: -79.2356 - val_sdep_func_tf: 10.8270
# Epoch 5/100
# 3/3 [==============================] - 0s 32ms/step - loss: 5081.5015 - mse: 5081.5015 - mean_absolute_error: 67.9987 - r2_func_tf: -44.3846 - rmse_func_tf: 68.0124 - bias_func_tf: -65.5841 - sdep_func_tf: 16.7264 - val_loss: 4943.5913 - val_mse: 4943.5913 - val_mean_absolute_error: 66.8470 - val_r2_func_tf: -inf - val_rmse_func_tf: 80.9472 - val_bias_func_tf: -79.2176 - val_sdep_func_tf: 10.8270
# Epoch 6/100
# 3/3 [==============================] - 0s 33ms/step - loss: 5079.1206 - mse: 5079.1206 - mean_absolute_error: 67.9811 - r2_func_tf: -23.0791 - rmse_func_tf: 67.6189 - bias_func_tf: -65.1450 - sdep_func_tf: 17.4115 - val_loss: 4941.4087 - val_mse: 4941.4087 - val_mean_absolute_error: 66.8307 - val_r2_func_tf: -inf - val_rmse_func_tf: 80.9312 - val_bias_func_tf: -79.2013 - val_sdep_func_tf: 10.8270
# Epoch 7/100
# 3/3 [==============================] - 0s 32ms/step - loss: 5076.9233 - mse: 5076.9233 - mean_absolute_error: 67.9651 - r2_func_tf: -44.3171 - rmse_func_tf: 69.1012 - bias_func_tf: -66.6119 - sdep_func_tf: 16.9361 - val_loss: 4939.4072 - val_mse: 4939.4072 - val_mean_absolute_error: 66.8157 - val_r2_func_tf: -inf - val_rmse_func_tf: 80.9166 - val_bias_func_tf: -79.1863 - val_sdep_func_tf: 10.8270
# Epoch 8/100
# 3/3 [==============================] - 0s 33ms/step - loss: 5074.9238 - mse: 5074.9238 - mean_absolute_error: 67.9504 - r2_func_tf: -9.7231 - rmse_func_tf: 71.6514 - bias_func_tf: -68.1625 - sdep_func_tf: 22.0358 - val_loss: 4937.5454 - val_mse: 4937.5454 - val_mean_absolute_error: 66.8018 - val_r2_func_tf: -inf - val_rmse_func_tf: 80.9030 - val_bias_func_tf: -79.1724 - val_sdep_func_tf: 10.8270
# Epoch 9/100
# 3/3 [==============================] - 0s 33ms/step - loss: 5073.0513 - mse: 5073.0513 - mean_absolute_error: 67.9367 - r2_func_tf: -10.9582 - rmse_func_tf: 69.9454 - bias_func_tf: -66.5447 - sdep_func_tf: 21.2281 - val_loss: 4935.8047 - val_mse: 4935.8047 - val_mean_absolute_error: 66.7887 - val_r2_func_tf: -inf - val_rmse_func_tf: 80.8903 - val_bias_func_tf: -79.1594 - val_sdep_func_tf: 10.8270
# Epoch 10/100
# 3/3 [==============================] - 0s 31ms/step - loss: 5071.3237 - mse: 5071.3237 - mean_absolute_error: 67.9239 - r2_func_tf: -11.5065 - rmse_func_tf: 70.8675 - bias_func_tf: -67.7671 - sdep_func_tf: 20.5688 - val_loss: 4934.1699 - val_mse: 4934.1699 - val_mean_absolute_error: 66.7765 - val_r2_func_tf: -inf - val_rmse_func_tf: 80.8784 - val_bias_func_tf: -79.1471 - val_sdep_func_tf: 10.8270
# Epoch 11/100
# 3/3 [==============================] - 0s 32ms/step - loss: 5069.6631 - mse: 5069.6631 - mean_absolute_error: 67.9118 - r2_func_tf: -10.2365 - rmse_func_tf: 73.0416 - bias_func_tf: -69.7076 - sdep_func_tf: 21.8132 - val_loss: 4932.6270 - val_mse: 4932.6270 - val_mean_absolute_error: 66.7649 - val_r2_func_tf: -inf - val_rmse_func_tf: 80.8671 - val_bias_func_tf: -79.1356 - val_sdep_func_tf: 10.8270
# Epoch 12/100
# 3/3 [==============================] - 0s 31ms/step - loss: 5068.1206 - mse: 5068.1206 - mean_absolute_error: 67.9004 - r2_func_tf: -9.7366 - rmse_func_tf: 72.5660 - bias_func_tf: -68.8506 - sdep_func_tf: 22.7298 - val_loss: 4931.1592 - val_mse: 4931.1592 - val_mean_absolute_error: 66.7539 - val_r2_func_tf: -inf - val_rmse_func_tf: 80.8564 - val_bias_func_tf: -79.1246 - val_sdep_func_tf: 10.8270
# Epoch 13/100
# 3/3 [==============================] - 0s 32ms/step - loss: 5066.6489 - mse: 5066.6489 - mean_absolute_error: 67.8895 - r2_func_tf: -12.3123 - rmse_func_tf: 72.4938 - bias_func_tf: -69.0323 - sdep_func_tf: 21.7024 - val_loss: 4929.7637 - val_mse: 4929.7637 - val_mean_absolute_error: 66.7435 - val_r2_func_tf: -inf - val_rmse_func_tf: 80.8462 - val_bias_func_tf: -79.1141 - val_sdep_func_tf: 10.8270
# Epoch 14/100
# 3/3 [==============================] - 0s 32ms/step - loss: 5065.2407 - mse: 5065.2407 - mean_absolute_error: 67.8792 - r2_func_tf: -9.8428 - rmse_func_tf: 72.2965 - bias_func_tf: -68.7975 - sdep_func_tf: 22.1629 - val_loss: 4928.4370 - val_mse: 4928.4370 - val_mean_absolute_error: 66.7335 - val_r2_func_tf: -inf - val_rmse_func_tf: 80.8365 - val_bias_func_tf: -79.1042 - val_sdep_func_tf: 10.8270
# Epoch 15/100
# 3/3 [==============================] - 0s 31ms/step - loss: 5063.9326 - mse: 5063.9326 - mean_absolute_error: 67.8693 - r2_func_tf: -67.8549 - rmse_func_tf: 68.0437 - bias_func_tf: -65.7145 - sdep_func_tf: 16.0186 - val_loss: 4927.1729 - val_mse: 4927.1729 - val_mean_absolute_error: 66.7241 - val_r2_func_tf: -inf - val_rmse_func_tf: 80.8273 - val_bias_func_tf: -79.0947 - val_sdep_func_tf: 10.8270
# Epoch 16/100
# 3/3 [==============================] - 0s 32ms/step - loss: 5062.6523 - mse: 5062.6523 - mean_absolute_error: 67.8600 - r2_func_tf: -9.8468 - rmse_func_tf: 69.9484 - bias_func_tf: -66.6036 - sdep_func_tf: 21.3210 - val_loss: 4925.9771 - val_mse: 4925.9771 - val_mean_absolute_error: 66.7151 - val_r2_func_tf: -inf - val_rmse_func_tf: 80.8186 - val_bias_func_tf: -79.0858 - val_sdep_func_tf: 10.8270
# Epoch 17/100
# 3/3 [==============================] - 0s 33ms/step - loss: 5061.4595 - mse: 5061.4595 - mean_absolute_error: 67.8511 - r2_func_tf: -33.7002 - rmse_func_tf: 67.6048 - bias_func_tf: -65.2404 - sdep_func_tf: 16.6488 - val_loss: 4924.8359 - val_mse: 4924.8359 - val_mean_absolute_error: 66.7066 - val_r2_func_tf: -inf - val_rmse_func_tf: 80.8102 - val_bias_func_tf: -79.0772 - val_sdep_func_tf: 10.8270
# Epoch 18/100
# 3/3 [==============================] - 0s 34ms/step - loss: 5060.2881 - mse: 5060.2881 - mean_absolute_error: 67.8427 - r2_func_tf: -9.9500 - rmse_func_tf: 70.9910 - bias_func_tf: -67.6497 - sdep_func_tf: 21.5066 - val_loss: 4923.7510 - val_mse: 4923.7510 - val_mean_absolute_error: 66.6984 - val_r2_func_tf: -inf - val_rmse_func_tf: 80.8023 - val_bias_func_tf: -79.0691 - val_sdep_func_tf: 10.8270
# Epoch 19/100
# 3/3 [==============================] - 0s 34ms/step - loss: 5059.2061 - mse: 5059.2061 - mean_absolute_error: 67.8346 - r2_func_tf: -16.8866 - rmse_func_tf: 69.4869 - bias_func_tf: -66.7731 - sdep_func_tf: 18.6850 - val_loss: 4922.7046 - val_mse: 4922.7046 - val_mean_absolute_error: 66.6906 - val_r2_func_tf: -inf - val_rmse_func_tf: 80.7946 - val_bias_func_tf: -79.0612 - val_sdep_func_tf: 10.8270
# Epoch 20/100
# 3/3 [==============================] - 0s 34ms/step - loss: 5058.1479 - mse: 5058.1479 - mean_absolute_error: 67.8268 - r2_func_tf: -15.7323 - rmse_func_tf: 68.7629 - bias_func_tf: -66.0733 - sdep_func_tf: 18.6340 - val_loss: 4921.6997 - val_mse: 4921.6997 - val_mean_absolute_error: 66.6830 - val_r2_func_tf: -inf - val_rmse_func_tf: 80.7873 - val_bias_func_tf: -79.0537 - val_sdep_func_tf: 10.8270
# Epoch 21/100
# 3/3 [==============================] - 0s 33ms/step - loss: 5057.1265 - mse: 5057.1265 - mean_absolute_error: 67.8194 - r2_func_tf: -10.7797 - rmse_func_tf: 71.8012 - bias_func_tf: -68.6165 - sdep_func_tf: 21.0814 - val_loss: 4920.7319 - val_mse: 4920.7319 - val_mean_absolute_error: 66.6758 - val_r2_func_tf: -inf - val_rmse_func_tf: 80.7802 - val_bias_func_tf: -79.0464 - val_sdep_func_tf: 10.8270
# Epoch 22/100
# 3/3 [==============================] - 0s 33ms/step - loss: 5056.1460 - mse: 5056.1460 - mean_absolute_error: 67.8122 - r2_func_tf: -10.4395 - rmse_func_tf: 73.1946 - bias_func_tf: -69.7757 - sdep_func_tf: 22.0159 - val_loss: 4919.7915 - val_mse: 4919.7915 - val_mean_absolute_error: 66.6687 - val_r2_func_tf: -inf - val_rmse_func_tf: 80.7733 - val_bias_func_tf: -79.0394 - val_sdep_func_tf: 10.8270
# Epoch 23/100
# 3/3 [==============================] - 0s 33ms/step - loss: 5055.1943 - mse: 5055.1943 - mean_absolute_error: 67.8052 - r2_func_tf: -10.1319 - rmse_func_tf: 72.9244 - bias_func_tf: -69.5533 - sdep_func_tf: 21.9075 - val_loss: 4918.8765 - val_mse: 4918.8765 - val_mean_absolute_error: 66.6619 - val_r2_func_tf: -inf - val_rmse_func_tf: 80.7667 - val_bias_func_tf: -79.0325 - val_sdep_func_tf: 10.8270
# Epoch 24/100
# ...
# Epoch 16/100
# 5/5 [==============================] - 0s 22ms/step - loss: 79.3515 - mse: 79.3515 - mean_absolute_error: 6.8364 - r2_func_tf: 0.8403 - rmse_func_tf: 8.7449 - bias_func_tf: -1.6190 - sdep_func_tf: 7.9561 - val_loss: 990.8317 - val_mse: 990.8317 - val_mean_absolute_error: 25.9423 - val_r2_func_tf: -1.6011 - val_rmse_func_tf: 31.4083 - val_bias_func_tf: -25.6987 - val_sdep_func_tf: 18.0496
# Epoch 17/100
# 5/5 [==============================] - 0s 21ms/step - loss: 73.4744 - mse: 73.4744 - mean_absolute_error: 6.2255 - r2_func_tf: 0.8447 - rmse_func_tf: 8.3315 - bias_func_tf: 0.8890 - sdep_func_tf: 8.2557 - val_loss: 912.2448 - val_mse: 912.2448 - val_mean_absolute_error: 24.4736 - val_r2_func_tf: -1.3918 - val_rmse_func_tf: 30.1304 - val_bias_func_tf: -24.1346 - val_sdep_func_tf: 18.0320
# Epoch 18/100
# 5/5 [==============================] - 0s 20ms/step - loss: 92.1292 - mse: 92.1292 - mean_absolute_error: 7.2062 - r2_func_tf: 0.7888 - rmse_func_tf: 9.5410 - bias_func_tf: 0.8536 - sdep_func_tf: 9.4759 - val_loss: 892.5687 - val_mse: 892.5687 - val_mean_absolute_error: 24.0945 - val_r2_func_tf: -1.3393 - val_rmse_func_tf: 29.8018 - val_bias_func_tf: -23.7319 - val_sdep_func_tf: 18.0208
# Epoch 19/100
# 5/5 [==============================] - 0s 21ms/step - loss: 90.2549 - mse: 90.2549 - mean_absolute_error: 6.6129 - r2_func_tf: 0.7651 - rmse_func_tf: 9.1379 - bias_func_tf: -0.6781 - sdep_func_tf: 8.9994 - val_loss: 883.9073 - val_mse: 883.9073 - val_mean_absolute_error: 23.9425 - val_r2_func_tf: -1.3164 - val_rmse_func_tf: 29.6564 - val_bias_func_tf: -23.5723 - val_sdep_func_tf: 17.9904
# Epoch 20/100
# 5/5 [==============================] - 0s 21ms/step - loss: 132.5186 - mse: 132.5186 - mean_absolute_error: 7.1953 - r2_func_tf: -1.2792 - rmse_func_tf: 10.0013 - bias_func_tf: 0.6665 - sdep_func_tf: 9.4805 - val_loss: 861.8425 - val_mse: 861.8425 - val_mean_absolute_error: 23.4980 - val_r2_func_tf: -1.2576 - val_rmse_func_tf: 29.2816 - val_bias_func_tf: -23.0999 - val_sdep_func_tf: 17.9898
# Epoch 21/100
# 5/5 [==============================] - 0s 20ms/step - loss: 101.6642 - mse: 101.6642 - mean_absolute_error: 7.0823 - r2_func_tf: 0.7045 - rmse_func_tf: 9.6718 - bias_func_tf: -1.9730 - sdep_func_tf: 9.3247 - val_loss: 831.7772 - val_mse: 831.7772 - val_mean_absolute_error: 22.8095 - val_r2_func_tf: -1.1771 - val_rmse_func_tf: 28.7620 - val_bias_func_tf: -22.3646 - val_sdep_func_tf: 18.0811
# Epoch 22/100
# 5/5 [==============================] - 0s 20ms/step - loss: 119.5554 - mse: 119.5554 - mean_absolute_error: 7.4994 - r2_func_tf: 0.5148 - rmse_func_tf: 10.8232 - bias_func_tf: -1.0636 - sdep_func_tf: 10.5817 - val_loss: 751.9545 - val_mse: 751.9545 - val_mean_absolute_error: 21.1507 - val_r2_func_tf: -0.9651 - val_rmse_func_tf: 27.3389 - val_bias_func_tf: -20.5511 - val_sdep_func_tf: 18.0272
# Epoch 23/100
# 5/5 [==============================] - 0s 20ms/step - loss: 49.9364 - mse: 49.9364 - mean_absolute_error: 5.2779 - r2_func_tf: 0.9000 - rmse_func_tf: 6.7990 - bias_func_tf: 1.2742 - sdep_func_tf: 6.4824 - val_loss: 718.0447 - val_mse: 718.0447 - val_mean_absolute_error: 20.3844 - val_r2_func_tf: -0.8749 - val_rmse_func_tf: 26.7108 - val_bias_func_tf: -19.6865 - val_sdep_func_tf: 18.0511
# Epoch 24/100
# 5/5 [==============================] - 0s 19ms/step - loss: 56.4714 - mse: 56.4714 - mean_absolute_error: 5.5651 - r2_func_tf: 0.8879 - rmse_func_tf: 7.2690 - bias_func_tf: 1.2299 - sdep_func_tf: 6.8614 - val_loss: 720.9680 - val_mse: 720.9680 - val_mean_absolute_error: 20.4662 - val_r2_func_tf: -0.8828 - val_rmse_func_tf: 26.7659 - val_bias_func_tf: -19.7868 - val_sdep_func_tf: 18.0230
# Epoch 25/100
# 5/5 [==============================] - 0s 20ms/step - loss: 50.7542 - mse: 50.7542 - mean_absolute_error: 5.5187 - r2_func_tf: 0.8911 - rmse_func_tf: 7.0515 - bias_func_tf: -0.9001 - sdep_func_tf: 6.7415 - val_loss: 722.1097 - val_mse: 722.1097 - val_mean_absolute_error: 20.5274 - val_r2_func_tf: -0.8861 - val_rmse_func_tf: 26.7879 - val_bias_func_tf: -19.8648 - val_sdep_func_tf: 17.9697
# Epoch 26/100
# 5/5 [==============================] - 0s 21ms/step - loss: 49.3026 - mse: 49.3026 - mean_absolute_error: 5.5690 - r2_func_tf: 0.8965 - rmse_func_tf: 7.0721 - bias_func_tf: -1.1579 - sdep_func_tf: 6.5643 - val_loss: 685.2944 - val_mse: 685.2944 - val_mean_absolute_error: 19.7335 - val_r2_func_tf: -0.7885 - val_rmse_func_tf: 26.0918 - val_bias_func_tf: -18.9576 - val_sdep_func_tf: 17.9261
# Epoch 27/100
# 5/5 [==============================] - 0s 21ms/step - loss: 88.1818 - mse: 88.1818 - mean_absolute_error: 5.9361 - r2_func_tf: 0.5582 - rmse_func_tf: 8.6651 - bias_func_tf: 0.0631 - sdep_func_tf: 8.5694 - val_loss: 659.9049 - val_mse: 659.9049 - val_mean_absolute_error: 19.1890 - val_r2_func_tf: -0.7212 - val_rmse_func_tf: 25.6008 - val_bias_func_tf: -18.3236 - val_sdep_func_tf: 17.8778
# Epoch 28/100
# 5/5 [==============================] - 0s 21ms/step - loss: 83.3506 - mse: 83.3506 - mean_absolute_error: 6.6052 - r2_func_tf: 0.7308 - rmse_func_tf: 8.9186 - bias_func_tf: -0.2716 - sdep_func_tf: 8.8377 - val_loss: 639.3024 - val_mse: 639.3024 - val_mean_absolute_error: 18.7369 - val_r2_func_tf: -0.6667 - val_rmse_func_tf: 25.1956 - val_bias_func_tf: -17.7986 - val_sdep_func_tf: 17.8326
# Epoch 29/100
# 5/5 [==============================] - 0s 22ms/step - loss: 48.7086 - mse: 48.7086 - mean_absolute_error: 5.4100 - r2_func_tf: 0.8963 - rmse_func_tf: 6.8021 - bias_func_tf: 0.3803 - sdep_func_tf: 6.7371 - val_loss: 626.3112 - val_mse: 626.3112 - val_mean_absolute_error: 18.4313 - val_r2_func_tf: -0.6323 - val_rmse_func_tf: 24.9363 - val_bias_func_tf: -17.4421 - val_sdep_func_tf: 17.8205
# Epoch 30/100
# 5/5 [==============================] - 0s 21ms/step - loss: 65.1673 - mse: 65.1673 - mean_absolute_error: 6.2035 - r2_func_tf: 0.8461 - rmse_func_tf: 8.1026 - bias_func_tf: 0.7468 - sdep_func_tf: 7.4785 - val_loss: 624.5610 - val_mse: 624.5610 - val_mean_absolute_error: 18.4092 - val_r2_func_tf: -0.6277 - val_rmse_func_tf: 24.9014 - val_bias_func_tf: -17.4249 - val_sdep_func_tf: 17.7887
# Epoch 31/100
# 5/5 [==============================] - 0s 20ms/step - loss: 52.3040 - mse: 52.3040 - mean_absolute_error: 5.7484 - r2_func_tf: 0.8672 - rmse_func_tf: 7.2307 - bias_func_tf: -0.7757 - sdep_func_tf: 6.9693 - val_loss: 636.5621 - val_mse: 636.5621 - val_mean_absolute_error: 18.7018 - val_r2_func_tf: -0.6596 - val_rmse_func_tf: 25.1414 - val_bias_func_tf: -17.7825 - val_sdep_func_tf: 17.7721
# Epoch 32/100
# 5/5 [==============================] - 0s 20ms/step - loss: 59.6508 - mse: 59.6508 - mean_absolute_error: 5.5563 - r2_func_tf: 0.8235 - rmse_func_tf: 7.4947 - bias_func_tf: -0.2449 - sdep_func_tf: 7.3049 - val_loss: 626.9390 - val_mse: 626.9390 - val_mean_absolute_error: 18.4914 - val_r2_func_tf: -0.6342 - val_rmse_func_tf: 24.9496 - val_bias_func_tf: -17.5444 - val_sdep_func_tf: 17.7386
# Epoch 33/100
# 5/5 [==============================] - 0s 20ms/step - loss: 48.1268 - mse: 48.1268 - mean_absolute_error: 5.3344 - r2_func_tf: 0.8835 - rmse_func_tf: 6.9096 - bias_func_tf: 0.3641 - sdep_func_tf: 6.4042 - val_loss: 622.4514 - val_mse: 622.4514 - val_mean_absolute_error: 18.4200 - val_r2_func_tf: -0.6224 - val_rmse_func_tf: 24.8600 - val_bias_func_tf: -17.4752 - val_sdep_func_tf: 17.6811
# Epoch 34/100
# 5/5 [==============================] - 0s 20ms/step - loss: 46.0705 - mse: 46.0705 - mean_absolute_error: 5.4597 - r2_func_tf: 0.9042 - rmse_func_tf: 6.7948 - bias_func_tf: -0.7726 - sdep_func_tf: 6.2313 - val_loss: 643.9249 - val_mse: 643.9249 - val_mean_absolute_error: 18.9418 - val_r2_func_tf: -0.6794 - val_rmse_func_tf: 25.2883 - val_bias_func_tf: -18.1059 - val_sdep_func_tf: 17.6534
# Epoch 35/100
# 5/5 [==============================] - 0s 26ms/step - loss: 42.4526 - mse: 42.4526 - mean_absolute_error: 4.8862 - r2_func_tf: 0.8857 - rmse_func_tf: 6.5434 - bias_func_tf: -0.2036 - sdep_func_tf: 6.2141 - val_loss: 632.3521 - val_mse: 632.3521 - val_mean_absolute_error: 18.7063 - val_r2_func_tf: -0.6488 - val_rmse_func_tf: 25.0590 - val_bias_func_tf: -17.8407 - val_sdep_func_tf: 17.5964
# Epoch 36/100
# 5/5 [==============================] - 0s 21ms/step - loss: 37.2697 - mse: 37.2697 - mean_absolute_error: 4.7375 - r2_func_tf: 0.9169 - rmse_func_tf: 6.1169 - bias_func_tf: -0.0328 - sdep_func_tf: 5.6517 - val_loss: 644.0695 - val_mse: 644.0695 - val_mean_absolute_error: 18.9940 - val_r2_func_tf: -0.6800 - val_rmse_func_tf: 25.2920 - val_bias_func_tf: -18.1940 - val_sdep_func_tf: 17.5679
# Epoch 37/100
# 5/5 [==============================] - 0s 21ms/step - loss: 38.5265 - mse: 38.5265 - mean_absolute_error: 4.8587 - r2_func_tf: 0.9139 - rmse_func_tf: 6.1241 - bias_func_tf: 0.0266 - sdep_func_tf: 5.7669 - val_loss: 637.4172 - val_mse: 637.4172 - val_mean_absolute_error: 18.8638 - val_r2_func_tf: -0.6625 - val_rmse_func_tf: 25.1606 - val_bias_func_tf: -18.0524 - val_sdep_func_tf: 17.5252
# Epoch 38/100
# 5/5 [==============================] - 0s 20ms/step - loss: 38.5562 - mse: 38.5562 - mean_absolute_error: 4.5263 - r2_func_tf: 0.8791 - rmse_func_tf: 6.2716 - bias_func_tf: 1.0494 - sdep_func_tf: 5.9562 - val_loss: 650.9300 - val_mse: 650.9300 - val_mean_absolute_error: 19.2084 - val_r2_func_tf: -0.6986 - val_rmse_func_tf: 25.4285 - val_bias_func_tf: -18.4756 - val_sdep_func_tf: 17.4705
# Epoch 39/100
# 5/5 [==============================] - 0s 19ms/step - loss: 45.2474 - mse: 45.2474 - mean_absolute_error: 5.1869 - r2_func_tf: 0.8787 - rmse_func_tf: 6.6685 - bias_func_tf: -0.1827 - sdep_func_tf: 6.5358 - val_loss: 689.1310 - val_mse: 689.1310 - val_mean_absolute_error: 20.0939 - val_r2_func_tf: -0.8000 - val_rmse_func_tf: 26.1693 - val_bias_func_tf: -19.4990 - val_sdep_func_tf: 17.4515
# Epoch 40/100
# 5/5 [==============================] - 0s 20ms/step - loss: 34.4139 - mse: 34.4139 - mean_absolute_error: 4.7004 - r2_func_tf: 0.9271 - rmse_func_tf: 5.8475 - bias_func_tf: -0.8081 - sdep_func_tf: 5.7780 - val_loss: 705.6851 - val_mse: 705.6851 - val_mean_absolute_error: 20.4912 - val_r2_func_tf: -0.8441 - val_rmse_func_tf: 26.4842 - val_bias_func_tf: -19.9465 - val_sdep_func_tf: 17.4204
# Epoch 41/100
# 5/5 [==============================] - 0s 21ms/step - loss: 34.5163 - mse: 34.5163 - mean_absolute_error: 4.6760 - r2_func_tf: 0.9242 - rmse_func_tf: 5.9180 - bias_func_tf: 0.1304 - sdep_func_tf: 5.4075 - val_loss: 715.3364 - val_mse: 715.3364 - val_mean_absolute_error: 20.7494 - val_r2_func_tf: -0.8701 - val_rmse_func_tf: 26.6668 - val_bias_func_tf: -20.2410 - val_sdep_func_tf: 17.3589
# Epoch 42/100
# 5/5 [==============================] - 0s 21ms/step - loss: 45.7007 - mse: 45.7007 - mean_absolute_error: 5.6308 - r2_func_tf: 0.8871 - rmse_func_tf: 6.6745 - bias_func_tf: -0.3767 - sdep_func_tf: 6.0840 - val_loss: 748.7192 - val_mse: 748.7192 - val_mean_absolute_error: 21.5288 - val_r2_func_tf: -0.9591 - val_rmse_func_tf: 27.2867 - val_bias_func_tf: -21.1053 - val_sdep_func_tf: 17.2921
# Epoch 43/100
# 5/5 [==============================] - 0s 21ms/step - loss: 56.2532 - mse: 56.2532 - mean_absolute_error: 5.1088 - r2_func_tf: 0.7279 - rmse_func_tf: 7.0680 - bias_func_tf: 0.0183 - sdep_func_tf: 6.9646 - val_loss: 773.7852 - val_mse: 773.7852 - val_mean_absolute_error: 22.0817 - val_r2_func_tf: -1.0258 - val_rmse_func_tf: 27.7426 - val_bias_func_tf: -21.6994 - val_sdep_func_tf: 17.2815
# Epoch 44/100
# 5/5 [==============================] - 0s 19ms/step - loss: 37.6608 - mse: 37.6608 - mean_absolute_error: 4.8538 - r2_func_tf: 0.9140 - rmse_func_tf: 6.1526 - bias_func_tf: -0.3375 - sdep_func_tf: 5.8940 - val_loss: 807.4446 - val_mse: 807.4446 - val_mean_absolute_error: 22.7989 - val_r2_func_tf: -1.1154 - val_rmse_func_tf: 28.3430 - val_bias_func_tf: -22.4690 - val_sdep_func_tf: 17.2716
# Epoch 45/100
# 5/5 [==============================] - 0s 19ms/step - loss: 34.5376 - mse: 34.5376 - mean_absolute_error: 4.6271 - r2_func_tf: 0.9264 - rmse_func_tf: 5.8276 - bias_func_tf: 0.3444 - sdep_func_tf: 5.6596 - val_loss: 828.2023 - val_mse: 828.2023 - val_mean_absolute_error: 23.2793 - val_r2_func_tf: -1.1710 - val_rmse_func_tf: 28.7079 - val_bias_func_tf: -22.9911 - val_sdep_func_tf: 17.1864
# Epoch 46/100
# 5/5 [==============================] - 0s 19ms/step - loss: 82.3098 - mse: 82.3098 - mean_absolute_error: 5.9947 - r2_func_tf: 0.5602 - rmse_func_tf: 8.4728 - bias_func_tf: -0.0503 - sdep_func_tf: 8.3930 - val_loss: 870.2056 - val_mse: 870.2056 - val_mean_absolute_error: 24.1579 - val_r2_func_tf: -1.2830 - val_rmse_func_tf: 29.4314 - val_bias_func_tf: -23.9365 - val_sdep_func_tf: 17.1183
# Epoch 47/100
# 5/5 [==============================] - 0s 20ms/step - loss: 35.8235 - mse: 35.8235 - mean_absolute_error: 4.8299 - r2_func_tf: 0.9227 - rmse_func_tf: 6.0629 - bias_func_tf: 0.6636 - sdep_func_tf: 5.7354 - val_loss: 920.1340 - val_mse: 920.1340 - val_mean_absolute_error: 25.1374 - val_r2_func_tf: -1.4159 - val_rmse_func_tf: 30.2680 - val_bias_func_tf: -24.9522 - val_sdep_func_tf: 17.1255
# Epoch 48/100
# 5/5 [==============================] - 0s 20ms/step - loss: 46.5319 - mse: 46.5319 - mean_absolute_error: 4.7684 - r2_func_tf: 0.8563 - rmse_func_tf: 6.4261 - bias_func_tf: 0.0783 - sdep_func_tf: 6.2708 - val_loss: 984.3994 - val_mse: 984.3994 - val_mean_absolute_error: 26.4013 - val_r2_func_tf: -1.5875 - val_rmse_func_tf: 31.3129 - val_bias_func_tf: -26.2606 - val_sdep_func_tf: 17.0463
# Epoch 49/100
# 5/5 [==============================] - 0s 19ms/step - loss: 33.9481 - mse: 33.9481 - mean_absolute_error: 4.4750 - r2_func_tf: 0.9303 - rmse_func_tf: 5.7825 - bias_func_tf: -0.6782 - sdep_func_tf: 5.4036 - val_loss: 1049.3025 - val_mse: 1049.3025 - val_mean_absolute_error: 27.6131 - val_r2_func_tf: -1.7610 - val_rmse_func_tf: 32.3340 - val_bias_func_tf: -27.5152 - val_sdep_func_tf: 16.9722
# Epoch 50/100
# 5/5 [==============================] - 0s 20ms/step - loss: 32.5061 - mse: 32.5061 - mean_absolute_error: 4.3245 - r2_func_tf: 0.9054 - rmse_func_tf: 5.7763 - bias_func_tf: -0.4330 - sdep_func_tf: 5.6060 - val_loss: 1104.7845 - val_mse: 1104.7845 - val_mean_absolute_error: 28.6102 - val_r2_func_tf: -1.9094 - val_rmse_func_tf: 33.1820 - val_bias_func_tf: -28.5475 - val_sdep_func_tf: 16.9028
# Epoch 51/100
# 5/5 [==============================] - 0s 20ms/step - loss: 49.8123 - mse: 49.8123 - mean_absolute_error: 5.3519 - r2_func_tf: 0.8717 - rmse_func_tf: 6.8823 - bias_func_tf: 0.3852 - sdep_func_tf: 6.3725 - val_loss: 1167.0693 - val_mse: 1167.0693 - val_mean_absolute_error: 29.6542 - val_r2_func_tf: -2.0758 - val_rmse_func_tf: 34.1084 - val_bias_func_tf: -29.6261 - val_sdep_func_tf: 16.8896
# Epoch 52/100
# 5/5 [==============================] - 0s 20ms/step - loss: 39.2599 - mse: 39.2599 - mean_absolute_error: 4.5954 - r2_func_tf: 0.9025 - rmse_func_tf: 6.1233 - bias_func_tf: 0.3161 - sdep_func_tf: 5.8278 - val_loss: 1254.6550 - val_mse: 1254.6550 - val_mean_absolute_error: 31.0708 - val_r2_func_tf: -2.3098 - val_rmse_func_tf: 35.3698 - val_bias_func_tf: -31.0708 - val_sdep_func_tf: 16.8868
# Epoch 53/100
# 1/5 [=====>........................] - ETA: 0s - loss: 32.2222 - mse: 32.2222 - mean_absolute_error: 4.4470 - r2_func_tf: 0.8908 - rmse_func_tf: 5.6765 - bias_func_tf: -1.4159 - sdep_func_tf: 5.4970Restoring model weights from the end of the best epoch: 33.
# 5/5 [==============================] - 0s 21ms/step - loss: 28.4191 - mse: 28.4191 - mean_absolute_error: 4.2553 - r2_func_tf: 0.9382 - rmse_func_tf: 5.2927 - bias_func_tf: 0.3415 - sdep_func_tf: 5.0773 - val_loss: 1336.6857 - val_mse: 1336.6857 - val_mean_absolute_error: 32.3589 - val_r2_func_tf: -2.5289 - val_rmse_func_tf: 36.5116 - val_bias_func_tf: -32.3589 - val_sdep_func_tf: 16.8966
# Epoch 53: early stopping

# %% [markdown]
# ## Fit model Tunner

# %%
def wrapped_train_val_split(hp_train_idx,hp_val_idx,x_train,y_train):
    x_hp_train = x_train.iloc[hp_train_idx].to_numpy()
    x_hp_val = x_train.iloc[hp_val_idx]
#     The next two lines (y) will vary depending on the CNN output

    y_train_df=[]
    for y_i in y_train:
       y_train_df.append(pd.DataFrame(y_i))

    y_train=y_train_df
    y_hp_train = [y_train[0].iloc[hp_train_idx],y_train[1].iloc[hp_train_idx],y_train[2].iloc[hp_train_idx],y_train[3].iloc[hp_train_idx]]
    y_hp_val  = [y_train[0].iloc[hp_val_idx] ,y_train[1].iloc[hp_val_idx] ,y_train[2].iloc[hp_val_idx] ,y_train[3].iloc[hp_val_idx]]
    
    # return padding(x_train), padding(x_test), df_np(y_train), df_np(y_test)
    return x_hp_train, x_hp_val, df_np(y_hp_train), df_np(y_hp_val)

# %%
mc_cv=1
n_folds=2
# Initialise train test split:
train_test_split = ShuffleSplit(mc_cv, test_size=test_frac, random_state=1)
train_test_split_hp = ShuffleSplit(2, test_size=0.3, random_state=1)
epochs=50

# resample=0
# Monte Carlo CV:

time_start=time.time()
resample=0
for train_idx, test_idx in train_test_split.split(x):
    resample+=1
    
    x_train, x_test, y_train, y_test = wrapped_train_test_split(train_idx,test_idx,file,prop)
    
    ### DEFINE MODEL
    es = EarlyStopping(monitor='val_loss', 
                       mode='min', 
                       verbose=1, 
                       patience=20, 
                       restore_best_weights=True)
    # CSV Logger
    csv_logger = CSVLogger(f"{resultdir}/csv_logger/model_history_log_resample_{resample}.csv", 
                           append=True)
    # # CP_callbacks
    # cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=f'{resultdir}/model_checkpoint/training_{resample}/cp.ckpt',
    #                                                  save_weights_only=True,
    #                                                  verbose=1)
    # TensorBoard
    tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=f'{resultdir}/tensorboard_logs/', #/{batch}', # _ADAPTIVELEARNIGNRATE_01_10_Dense3_64_3CNN_lr_3_es
                                                          update_freq = 1,
                                                          # histogram_freq=1, 
                                                          write_graph=False, 
                                                          write_images=False)
    # https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/TensorBoard
    
    # Covert to list and provide to Keras Regressor
    # keras_callbacks = [es, csv_logger, cp_callback,tensorboard_callback]
    keras_callbacks = [es, csv_logger, tensorboard_callback]
        
    # ###initialise model
    # model = KerasRegressor(model=build_model, 
    #                        batch=16,
    #                         epochs=epochs,
    #                         verbose=1,
    #                         validation_split=0.3,
    #                        callbacks=keras_callbacks)
    #                        # dense1=1,
    #                        #  dense2=1,
    #                        #  dense3=1)

    # ### PIPE
    # # Define inputs for pipe
    # scaler = StandardScaler()
 
    # model_name='model'
    # # Do we have to redefine the pipe? Think Dans code and data leakage
    # # NB! "model" must match the model__
    # # pipe = Pipeline(steps=[("scaler", scaler), (f"{model_name}", model )] )
    # pipe = Pipeline(steps=[("scaler", scaler), (f"{model_name}",model_for_grid2(resultdir,resample))])
    # # model_for_grid(resultdir,resample,epochs))])

    # ###define scoring dict for cv
    # scorers = {
    #     'r2':make_scorer(r2_func), 
    #     'rmse':make_scorer(rmse_func, greater_is_better=False), 
    #     'bias':make_scorer(bias_func, greater_is_better=False), 
    #     'sdep':make_scorer(sdep_func, greater_is_better=False)
    #     }
    # ###parameter grid
    # # param_grid_model = {                     
    # #              "dense1":[32],
    # #              "dense2":[32],
    # #              "dense3":[2,32]}
    # param_grid_model = {
    #                  "model__dense1":[32],
    #                  "model__dense2":[32],
    #                  "model__dense3":[2,32]}
    
    # ###create CV using sklearn.GridSearchCV
    # grid = GridSearchCV(
    #     estimator=pipe, 
    #     # estimator=model_for_grid(resultdir,resample,epochs),
    #     # estimator=model,
    #     param_grid=param_grid_model,
    #     n_jobs=1, 
    #     cv=n_folds, 
    #     refit='rmse', 
    #     scoring=scorers, 
    #     return_train_score=True,
        
    #     )
    batch=16
    
    #########################################
    # tuner = kt.GridSearch(build_model,
    #                    objective='val_loss',
    #                    # objective = ['val_mse','epoch_entropy_pred_mse','val_free_energy_pred_mse'],
    #                   directory=os.getcwd()+'/hyper_param_tunning_tunner_outside_hp',
    #                   overwrite=True,
    #                   project_name=f'{batch}')
    fold=0
    for hp_train_idx, hp_val_idx in train_test_split_hp.split(pd.DataFrame(x_train)):
        fold+=1
        x_hp_train, x_hp_val, y_hp_train, y_hp_val = wrapped_train_val_split(hp_train_idx,hp_val_idx,pd.DataFrame(x_train),y_train)

        ### DEFINE MODEL
        es_hp = EarlyStopping(monitor='val_loss', 
                           mode='min', 
                           verbose=1, 
                           patience=20, 
                           restore_best_weights=True)
        # CSV Logger
        csv_logger_hp = CSVLogger(f"{resultdir}/csv_logger/model_history_log_resample_{resample}_{fold}_hp.csv", 
                               append=True)
        # # CP_callbacks
        # cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=f'{resultdir}/model_checkpoint/training_{resample}/cp.ckpt',
        #                                                  save_weights_only=True,
        #                                                  verbose=1)
        # TensorBoard
        tensorboard_callback_hp = tf.keras.callbacks.TensorBoard(log_dir=f'{resultdir}/tensorboard_logs_hp/resample_{resample}_fold_{fold}/', #/{batch}', # _ADAPTIVELEARNIGNRATE_01_10_Dense3_64_3CNN_lr_3_es
                                                              update_freq = 1,
                                                              # histogram_freq=1, 
                                                              write_graph=False, 
                                                              write_images=False)
        # https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/TensorBoard
        
        # Covert to list and provide to Keras Regressor
        # keras_callbacks = [es, csv_logger, cp_callback,tensorboard_callback]
        keras_callbacks_hp = [es_hp, csv_logger_hp, tensorboard_callback_hp]
        
        tuner = kt.GridSearch(build_model,
                           objective='val_loss',
                           # objective = ['val_mse','epoch_entropy_pred_mse','val_free_energy_pred_mse'],
                          directory=os.getcwd()+f'/hyper_param_tunning_tunner/fold_{fold}',
                          overwrite=False,
                          project_name=f'{batch}')
        tuner.search(x_hp_train, y_hp_train[0],
                    epochs = epochs,
                    batch_size=16,
                    verbose = 1,
                    validation_data =(x_hp_val, y_hp_val[0]),
                     # validation_split = 0.2,
                    callbacks=keras_callbacks_hp)
                     # callbacks=[es1, csv_logger1, cp_callback1, tensorboard_callback1])


    
    ###fit the model
    # history = grid.fit(x_train, y_train[0], 
    #                 # epochs=epochs,
    #                 # verbose=1,
    #                 # validation_split=0.2,
    #                 # callbacks=keras_callbacks1
    #                 )

   
        
total_time=time.time()-time_start
# Out:
# Trial 2 Complete [00h 00m 08s]
# val_loss: 33.880374908447266
#
# Best val_loss So Far: 32.32048416137695
# Total elapsed time: 00h 00m 17s

# %%
tuner = kt.GridSearch(build_model,
                           objective='val_loss',
                           # objective = ['val_mse','epoch_entropy_pred_mse','val_free_energy_pred_mse'],
                          directory=os.getcwd()+'/hyper_param_tunning_tunner',
                          overwrite=True,
                          project_name=f'{batch}')

# x_hp_train.shape

# %%
# tuner.results_summary()

# tuner.search(x_hp_train, y_hp_train[0],
#             epochs = epochs,
#             batch_size=16,
#             verbose = 1,
#             validation_data =(x_hp_val, y_hp_val[0]),
#              # validation_split = 0.2,
#             callbacks=keras_callbacks_hp)
# y_hp_train[0]
# tuner.get_state()
tuner.results_summary()
# Out:
# Results summary
# Results in /users/qdb16186/CNN_jony/hyper_param_tunning_tunner/fold_2/16
# Showing 10 best trials
# Objective(name="val_loss", direction="min")
#
# Trial 0000 summary
# Hyperparameters:
# model_type1: CNN3
# model_type: Dense3
# layer_3_1: 32
# layer_3_2: 32
# layer_3_3: 2
# Score: 32.32048416137695
#
# Trial 0001 summary
# Hyperparameters:
# model_type1: CNN3
# model_type: Dense3
# layer_3_1: 32
# layer_3_2: 32
# layer_3_3: 32
# Score: 33.880374908447266

# %% [markdown]
# # Sci-kit learn KNN and RF

# %%
mc_cv=1
train_test_split = ShuffleSplit(mc_cv, test_size=test_frac, random_state=1)
for train_idx, test_idx in train_test_split.split(x):
    print(train_idx)
# Out:
# [188 290 192 224 284 267  19  14  91 208 174  44 171 150 297 278  41  79
#  288 231 164 117 256  99 266   8 236 189 197  31 293  55  28 291 246 175
#   48 249  33  35 212  63 225 234  66 154 303 240 204  47 228 214  40  21
#  101  69  53 137  24 242 134 210 116 167 142 285 245 217  56  61 179 180
#   84 184 114 292 258 118 279 170 145 299 265  54 176 272 186 201 238  98
#  206 130  97 275  82 193  60  94 140 233 148 152 274 135  81 124 243 244
#   13  96 250 263  45 286 103  36 273  20 269 218  75 200 227 282 300 149
#  268   2 198 213  52   6 205 128 270  77 113  65 183 151 277 160  46 190
#   74  92 199 262  87 239 143 301  10 162  32 136 166  83  57 165 155 100
#  125  23 126 195 294 104 153 226  25 196  64  15 109  26  76  43   3  49
#  296  30 121 115 283 216 264 209   1  22   7 141  86 241 215  68  50 156
#  252 254 276 178 281 237  71 129 144 133 203 255  72 235  37]

# %% [markdown]
# ## RF

# %%
import time

# %%
mc_cv=50
n_folds=5
n_jobs=16
home=os.getcwd()
# time_start=time.time()
# Initialise train test split:
train_test_split = ShuffleSplit(mc_cv, test_size=test_frac, random_state=1)
train_test_split_hp = ShuffleSplit(2, test_size=0.3, random_state=1)

# Monte Carlo CV:
# time_start=time.time()
resample=0
for train_idx, test_idx in train_test_split.split(x):
    resample+=1

    ###define scoring dict for cv
    scorers = {
        'r2':make_scorer(r2_func), 
        'rmse':make_scorer(rmse_func, greater_is_better=False), 
        'bias':make_scorer(bias_func, greater_is_better=False), 
        'sdep':make_scorer(sdep_func, greater_is_better=False)
        }

    #########################################
    
    ### DEFINE MODEL
    model_name = 'RF'
    model = RandomForestRegressor()
    
    ### Grid
    
    pipe_cond='No_scalling'
    for pipe_cond in ['No_scalling','Scalling']:
        if pipe_cond=="Scalling":        
            param_grid_model = [{'RF__n_estimators':(100,150,300),
                                 'RF__min_samples_split':(2,4),#,6,7,10,14),
                                 'RF__min_samples_leaf':(1,2),#,3,5,7),
                               'RF__max_depth':(10,30),#,60,90,None),
                               'RF__max_features':('sqrt', 'log2', None, 1, 0.2, 0.3, 0.6, 0.7)}]

            ### PIPE
            # Define inputs for pipe
            scaler = StandardScaler()
            pipe = Pipeline(steps=[("scaler", scaler), (f"{model_name}",model)])

            ###create CV using sklearn.GridSearchCV
            grid = GridSearchCV(
                estimator=pipe, 
                param_grid=param_grid_model,
                n_jobs=n_jobs, 
                cv=n_folds, 
                refit='rmse', 
                scoring=scorers, 
                return_train_score=True,
                )

        else:
            param_grid = [{'n_estimators':(80,160),
                                 'min_samples_split':(2,4,6,7),#,6,7,10,14),
                                 'min_samples_leaf':(1,2,3,5,6),#,3,5,7),
                               'max_depth':(10,30,60,None),
                               'max_features':(0.6, 0.7,0.8)}]

            ### PIPE
            # Define inputs for pipe
            scaler = StandardScaler()
            pipe = Pipeline(steps=[("scaler", scaler), (f"{model_name}",model)])

            ###create CV using sklearn.GridSearchCV
            grid = GridSearchCV(
                estimator=model, 
                param_grid=param_grid,
                n_jobs=n_jobs, 
                cv=n_folds, 
                refit='rmse',#'rmse', 
                scoring=scorers, 
                return_train_score=True,
                )


        ### CV Train test split
        # x_train, x_test, y_train, y_test = wrapped_train_test_split(train_idx,test_idx,file,prop)
        ### Sci-kit learn models reuire X and y_1 to y_4
    #     Open a for loop
        prop='Granulated'
        # desc_type = ['RF-Score','H-Bonding','Granulated','DNA-Groups','OHEP','LP_dec2','CountDNA','CountDNAp']
        desc_type = ['RF-Score','H-Bonding','Granulated','DNA-Groups','OHEP','LP_dec2','CountDNA','CountDNAp']
        for prop in desc_type:
            
        #     adjust y[2] to * Temperature /1000 dS*T kcal/mol
            x_train, x_test, y_train, y_test = wrapped_train_test_split_no_padding(train_idx,test_idx,file,prop)

            ### FIT MODEL AND EVALUTATE IT
            ###fit the model
        #     Open a for loop
            GSHT_list=['dH','dS','dG','Tm'] #get the order correct
            GSHT='dH'
            i=-1
            for GSHT in GSHT_list:
                i+=1
                path="{}/CV/{}/{}/{}/{}".format(os.getcwd(),resample,model_name,prop,GSHT)
            #             print(os.getcwd)
            # home=os.getcwd()
                create_dir(home,resample,model_name,prop,GSHT)

                history = grid.fit(x_train, y_train[i])
    
                
                results=pd.DataFrame(history.cv_results_)
                results.to_csv(path+f"/gridsearch_resample_{resample}_pipe_cond_{pipe_cond}.csv")

                # param=dict(results['params'][history.best_index_])
                # model2=KNeighborsRegressor()
                # model2.set_params(**param)
                # model_fitted=model2.fit(x_train,y_train[0])
                y_pred_test=history.predict(x_test)
                y_pred_train=history.predict(x_train)
                # y_pred_test=model_fitted.predict(x_test)
                # y_pred_train=model_fitted.predict(x_train)

                save_splits(train_idx,y_train[i],y_pred_train,resample,path,f"train_pipe_cond_{pipe_cond}")
                save_splits(test_idx,y_test[i],y_pred_test,resample,path,f"test_pipe_cond_{pipe_cond}")
        
# total_time=time.time()-time_start
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [19], in <cell line: 13>()
#     102 #             print(os.getcwd)
#     103 # home=os.getcwd()
#     104     create_dir(home,resample,model_name,prop,GSHT)
# --> 106     history = grid.fit(x_train, y_train[i])
#     109     results=pd.DataFrame(history.cv_results_)
#     110     results.to_csv(path+f"/gridsearch_resample_{resample}_pipe_cond_{pipe_cond}.csv")
#
# File ~/opt/anaconda3/envs/linear/lib/python3.9/site-packages/sklearn/model_selection/_search.py:874, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     868     results = self._format_results(
#     869         all_candidate_params, n_splits, all_out, all_more_results
#     870     )
#     872     return results
# --> 874 self._run_search(evaluate_candidates)
#     876 # multimetric is determined here because in the case of a callable
#     877 # self.scoring the return type is only known after calling
#     878 first_test_score = all_out[0]["test_scores"]
#
# File ~/opt/anaconda3/envs/linear/lib/python3.9/site-packages/sklearn/model_selection/_search.py:1388, in GridSearchCV._run_search(self, evaluate_candidates)
#    1386 def _run_search(self, evaluate_candidates):
#    1387     """Search all candidates in param_grid"""
# -> 1388     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~/opt/anaconda3/envs/linear/lib/python3.9/site-packages/sklearn/model_selection/_search.py:821, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     813 if self.verbose > 0:
#     814     print(
#     815         "Fitting {0} folds for each of {1} candidates,"
#     816         " totalling {2} fits".format(
#     817             n_splits, n_candidates, n_candidates * n_splits
#     818         )
#     819     )
# --> 821 out = parallel(
#     822     delayed(_fit_and_score)(
#     823         clone(base_estimator),
#     824         X,
#     825         y,
#     826         train=train,
#     827         test=test,
#     828         parameters=parameters,
#     829         split_progress=(split_idx, n_splits),
#     830         candidate_progress=(cand_idx, n_candidates),
#     831         **fit_and_score_kwargs,
#     832     )
#     833     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     834         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     835     )
#     836 )
#     838 if len(out) < 1:
#     839     raise ValueError(
#     840         "No fits were performed. "
#     841         "Was the CV iterator empty? "
#     842         "Were there no candidates?"
#     843     )
#
# File ~/opt/anaconda3/envs/linear/lib/python3.9/site-packages/sklearn/utils/parallel.py:63, in Parallel.__call__(self, iterable)
#      58 config = get_config()
#      59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
# ---> 63 return super().__call__(iterable_with_config)
#
# File ~/opt/anaconda3/envs/linear/lib/python3.9/site-packages/joblib/parallel.py:1098, in Parallel.__call__(self, iterable)
#    1095     self._iterating = False
#    1097 with self._backend.retrieval_context():
# -> 1098     self.retrieve()
#    1099 # Make sure that we get a last message telling us we are done
#    1100 elapsed_time = time.time() - self._start_time
#
# File ~/opt/anaconda3/envs/linear/lib/python3.9/site-packages/joblib/parallel.py:975, in Parallel.retrieve(self)
#     973 try:
#     974     if getattr(self._backend, 'supports_timeout', False):
# --> 975         self._output.extend(job.get(timeout=self.timeout))
#     976     else:
#     977         self._output.extend(job.get())
#
# File ~/opt/anaconda3/envs/linear/lib/python3.9/site-packages/joblib/_parallel_backends.py:567, in LokyBackend.wrap_future_result(future, timeout)
#     564 """Wrapper for Future.result to implement the same behaviour as
#     565 AsyncResults.get from multiprocessing."""
#     566 try:
# --> 567     return future.result(timeout=timeout)
#     568 except CfTimeoutError as e:
#     569     raise TimeoutError from e
#
# File ~/opt/anaconda3/envs/linear/lib/python3.9/concurrent/futures/_base.py:441, in Future.result(self, timeout)
#     438 elif self._state == FINISHED:
#     439     return self.__get_result()
# --> 441 self._condition.wait(timeout)
#     443 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     444     raise CancelledError()
#
# File ~/opt/anaconda3/envs/linear/lib/python3.9/threading.py:312, in Condition.wait(self, timeout)
#     310 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311     if timeout is None:
# --> 312         waiter.acquire()
#     313         gotit = True
#     314     else:
#
# KeyboardInterrupt:

# %%
grid.param_grid
path
total_time
# i
total_time/60*50/60
# Out:
# 17.377675986952248

# %% [markdown]
# ## KNN

# %%
mc_cv=50
n_folds=10
n_jobs=4
home=os.getcwd()

# Initialise train test split:
train_test_split = ShuffleSplit(mc_cv, test_size=test_frac, random_state=1)
train_test_split_hp = ShuffleSplit(2, test_size=0.3, random_state=1)

# Monte Carlo CV:
# time_start=time.time()
resample=0
for train_idx, test_idx in train_test_split.split(x):
    resample+=1

    ###define scoring dict for cv
    scorers = {
        'r2':make_scorer(r2_func), 
        'rmse':make_scorer(rmse_func, greater_is_better=False), 
        'bias':make_scorer(bias_func, greater_is_better=False), 
        'sdep':make_scorer(sdep_func, greater_is_better=False)
        }

    #########################################
    
    ### DEFINE MODEL
    model_name = 'KNN'
    model = KNeighborsRegressor()
    
    ### Grid
    
    pipe_cond='No_scalling'
    for pipe_cond in ['No_scalling','Scalling']:
        if pipe_cond=="Scalling":        
            param_grid_model = [{'KNN__n_neighbors':(3,5,7,9,11,13,15,17,19),
                                 'KNN__weights':('uniform','distance'),
                                 'KNN__p':(1,2)}]
                           # {'n_neighbors':(3,5,7,9,11,13,15,17,19),'weights':('uniform','distance'),'p':(1,2),
                           #  'algorithm':('ball_tree', 'kd_tree'),'leaf_size':(20,30,40,60)}]

            ### PIPE
            # Define inputs for pipe
            scaler = StandardScaler()
            pipe = Pipeline(steps=[("scaler", scaler), (f"{model_name}",model)])

            ###create CV using sklearn.GridSearchCV
            grid = GridSearchCV(
                estimator=pipe, 
                param_grid=param_grid_model,
                n_jobs=n_jobs, 
                cv=n_folds, 
                refit='rmse', 
                scoring=scorers, 
                return_train_score=True,
                )

        else:
            param_grid = [{'n_neighbors':(3,5,7,9,11,13,15,17,19),
                           'weights':('uniform','distance'),
                           'p':(1,2)}]
                       # {'n_neighbors':(3,5,7,9,11,13,15,17,19),'weights':('uniform','distance'),'p':(1,2),
                       #  'algorithm':('ball_tree', 'kd_tree'),'leaf_size':(20,30,40,60)}]

            ### PIPE
            # Define inputs for pipe
            scaler = StandardScaler()
            pipe = Pipeline(steps=[("scaler", scaler), (f"{model_name}",model)])

            ###create CV using sklearn.GridSearchCV
            grid = GridSearchCV(
                estimator=model, 
                param_grid=param_grid,
                n_jobs=n_jobs, 
                cv=n_folds, 
                refit='rmse',#'rmse', 
                scoring=scorers, 
                return_train_score=True,
                )


        ### CV Train test split
        # x_train, x_test, y_train, y_test = wrapped_train_test_split(train_idx,test_idx,file,prop)
        ### Sci-kit learn models reuire X and y_1 to y_4
    #     Open a for loop
        prop='Granulated'
        # desc_type = ['RF-Score','H-Bonding','Granulated','DNA-Groups','OHEP','LP_dec2','CountDNA','CountDNAp']
        for prop in desc_type:
        #     adjust y[2] to * Temperature /1000 dS*T kcal/mol
            x_train, x_test, y_train, y_test = wrapped_train_test_split_no_padding(train_idx,test_idx,file,prop)

            ### FIT MODEL AND EVALUTATE IT
            ###fit the model
        #     Open a for loop
            GSHT_list=['dH','dS','dG','Tm'] #get the order correct
            GSHT='dH'
            i=-1
            for GSHT in GSHT_list:
                i+=1
                history = grid.fit(x_train, y_train[i])

                path="{}/CV/{}/{}/{}/{}".format(os.getcwd(),resample,model_name,prop,GSHT)
            #             print(os.getcwd)
            # home=os.getcwd()
                create_dir(home,resample,model_name,prop,GSHT)

                results=pd.DataFrame(history.cv_results_)
                results.to_csv(path+f"/gridsearch_resample_{resample}_pipe_cond_{pipe_cond}.csv")

                # param=dict(results['params'][history.best_index_])
                # model2=KNeighborsRegressor()
                # model2.set_params(**param)
                # model_fitted=model2.fit(x_train,y_train[0])
                y_pred_test=history.predict(x_test)
                y_pred_train=history.predict(x_train)
                # y_pred_test=model_fitted.predict(x_test)
                # y_pred_train=model_fitted.predict(x_train)

                save_splits(train_idx,y_train[i],y_pred_train,resample,path,f"train_pipe_cond_{pipe_cond}")
                save_splits(test_idx,y_test[i],y_pred_test,resample,path,f"test_pipe_cond_{pipe_cond}")
        
# total_time=time.time()-time_start

# %%
history.score
history.best_params_
# Out:
# {'KNN__n_neighbors': 5, 'KNN__p': 2, 'KNN__weights': 'distance'}

# %%
y_outputs = pd.DataFrame()
y_outputs['ID'] = test_idx
# y_outputs.to_csv(f'{path}/Split_{resample}_type_.csv'), index=False)
y_outputs.to_csv(f'{path}/Split_{resample}_type_.csv')
path
# Out:
# '/Users/ivanyankov/Documents/CNN_Dec/CNN_jony/CV/1/model/'

# %%
param
history.best_index_
# Out:
# 0

# %%
def save_splits(idx,true,pred,resample,path,split_type):
    y_outputs = pd.DataFrame()
    y_outputs['ID'] = idx
    y_outputs['y_true'] = true
    y_outputs['y_pred'] = pred
    y_outputs.to_csv(f'{path}/Split_{resample}_type_{split_type}.csv', index=False)
    return

# %%
def create_dir(home,resample,model_name,prop,GSHT):
    if home==None:
        home=os.getcwd()
    try:
            os.mkdir("{}/CV/".format(home))
    except:
            pass
    os.chdir("{}/CV/".format(home))
    try:
        os.mkdir("{}".format(resample))
    except:
            pass
    os.chdir("{}".format(resample))
    try:
        os.mkdir("{}".format(model_name))
    except:
            pass
    os.chdir("{}".format(model_name))
    try:
        os.mkdir("{}".format(prop))
    except:
            pass
    os.chdir("{}".format(prop))
    try:
        os.mkdir("{}".format(GSHT))
    except:
            pass
    os.chdir("{}".format(GSHT))

    os.chdir("{}".format(home))
    return

# %%
home=os.getcwd()
home
# Out:
# '/Users/ivanyankov/Documents/CNN_Dec/CNN_jony'

# %%
x_train
file
# Out:
#       ID Branch               DNA     dH     dS    dG    Tm  RF-Score_C----C  \
# 0      1    8DD          aaaaaaaa  -46.3 -134.0  -4.7  16.9             2801
# 1      2    8DD         aaaaaaaaa  -59.8 -173.0  -6.1  27.9             3281
# 2      3    8DD        aaaaaaaaaa  -78.3 -231.0  -6.7  32.0             3753
# 3      4     1A          aactggac  -59.8 -168.0  -7.8  35.7             2656
# 4      5    5AA          aagcgtag  -55.4 -153.0  -8.0  37.0             2646
# ..   ...    ...               ...    ...    ...   ...   ...              ...
# 300  301    5AA          ttcattcc  -50.0 -140.0  -6.5  28.7             2669
# 301  302     1A          ttctggac  -56.2 -158.0  -7.3  32.9             2621
# 302  303    5AA  ttgaagatacgctggc -119.0 -322.0 -19.0  69.2             5775
# 303  304     1A          ttgtggac  -55.5 -154.0  -7.8  35.8             2610
# 304  305     1A          ttttggac  -56.4 -160.0  -6.7  30.7             2666
#
#      RF-Score_N----C  RF-Score_O----C  ...  CountDNA_pos_A  CountDNA_pos_G  \
# 0               1752             1162  ...               8               0
# 1               2019             1424  ...               9               0
# 2               2309             1601  ...              10               0
# 3               1372             1441  ...               3               2
# 4               1418             1441  ...               3               3
# ..               ...              ...  ...             ...             ...
# 300              986             1715  ...               1               0
# 301             1172             1584  ...               1               2
# 302             2985             3074  ...               4               5
# 303             1236             1551  ...               1               3
# 304             1124             1634  ...               1               2
#
#      CountDNA_pos_C  CountDNA_pos_T  CountDNA_pos_Tot  CountDNAp_pos_A  \
# 0                 0               0                 8            1.000
# 1                 0               0                 9            1.000
# 2                 0               0                10            1.000
# 3                 2               1                 8            0.375
# 4                 1               1                 8            0.375
# ..              ...             ...               ...              ...
# 300               3               4                 8            0.125
# 301               2               3                 8            0.125
# 302               3               4                16            0.250
# 303               1               3                 8            0.125
# 304               1               4                 8            0.125
#
#      CountDNAp_pos_G  CountDNAp_pos_C  CountDNAp_pos_T  CountDNAp_pos_Tot
# 0             0.0000           0.0000            0.000                  8
# 1             0.0000           0.0000            0.000                  9
# 2             0.0000           0.0000            0.000                 10
# 3             0.2500           0.2500            0.125                  8
# 4             0.3750           0.1250            0.125                  8
# ..               ...              ...              ...                ...
# 300           0.0000           0.3750            0.500                  8
# 301           0.2500           0.2500            0.375                  8
# 302           0.3125           0.1875            0.250                 16
# 303           0.3750           0.1250            0.375                  8
# 304           0.2500           0.1250            0.500                  8
#
# [305 rows x 383 columns]

# %% [markdown]
# # Analysis

# %%
print(total_time)
# grid.best_estimator_
tuner.get_best_hyperparameters()
tuner.results_summary()
# Out:
# 0.017025232315063477
# Results summary
# Results in /users/qdb16186/CNN_jony/hyper_param_tunning_tunner/16
# Showing 10 best trials
# Objective(name="val_loss", direction="min")
#
# Trial 0000 summary
# Hyperparameters:
# model_type1: CNN3
# model_type: Dense3
# layer_3_1: 32
# layer_3_2: 32
# layer_3_3: 2
# Traceback (most recent call last):
#   File "/users/qdb16186/.local/lib/python3.9/site-packages/keras_tuner/src/engine/base_tuner.py", line 273, in _try_run_and_update_trial
#     self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#   File "/users/qdb16186/.local/lib/python3.9/site-packages/keras_tuner/src/engine/base_tuner.py", line 238, in _run_and_update_trial
#     results = self.run_trial(trial, *fit_args, **fit_kwargs)
#   File "/users/qdb16186/.local/lib/python3.9/site-packages/keras_tuner/src/engine/tuner.py", line 314, in run_trial
#     obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#   File "/users/qdb16186/.local/lib/python3.9/site-packages/keras_tuner/src/engine/tuner.py", line 233, in _build_and_fit_model
#     results = self.hypermodel.fit(hp, model, *args, **kwargs)
#   File "/users/qdb16186/.local/lib/python3.9/site-packages/keras_tuner/src/engine/hypermodel.py", line 149, in fit
#     return model.fit(*args, **kwargs)
#   File "/users/qdb16186/.local/lib/python3.9/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/users/qdb16186/.local/lib/python3.9/site-packages/tensorflow/python/trackable/data_structures.py", line 823, in __getattribute__
#     return super().__getattribute__(name)
# TypeError: this __dict__ descriptor does not support '_DictWrapper' objects
#
#
# Trial 0001 summary
# Hyperparameters:
# model_type1: CNN3
# model_type: Dense3
# layer_3_1: 32
# layer_3_2: 32
# layer_3_3: 32
# Traceback (most recent call last):
#   File "/users/qdb16186/.local/lib/python3.9/site-packages/keras_tuner/src/engine/base_tuner.py", line 273, in _try_run_and_update_trial
#     self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#   File "/users/qdb16186/.local/lib/python3.9/site-packages/keras_tuner/src/engine/base_tuner.py", line 238, in _run_and_update_trial
#     results = self.run_trial(trial, *fit_args, **fit_kwargs)
#   File "/users/qdb16186/.local/lib/python3.9/site-packages/keras_tuner/src/engine/tuner.py", line 314, in run_trial
#     obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#   File "/users/qdb16186/.local/lib/python3.9/site-packages/keras_tuner/src/engine/tuner.py", line 233, in _build_and_fit_model
#     results = self.hypermodel.fit(hp, model, *args, **kwargs)
#   File "/users/qdb16186/.local/lib/python3.9/site-packages/keras_tuner/src/engine/hypermodel.py", line 149, in fit
#     return model.fit(*args, **kwargs)
#   File "/users/qdb16186/.local/lib/python3.9/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/users/qdb16186/.local/lib/python3.9/site-packages/tensorflow/python/trackable/data_structures.py", line 823, in __getattribute__
#     return super().__getattribute__(name)
# TypeError: this __dict__ descriptor does not support '_DictWrapper' objects

# %%
# model.get_params().keys()
grid.cv_results_
grid.best_params_
grid.param_grid
# Out:
# {'model__dense1': [32], 'model__dense2': [32], 'model__dense3': [2, 32]}

# %%
# ###fit the model
# history = grid.fit(nxtr, ytr, 
#                 epochs=epochs,
#                 verbose=1,
#                 validation_split=0.2,
#                 callbacks=keras_callbacks
#                 )
pd.DataFrame(grid.cv_results_).to_csv("cv_results_2.csv")

# %%
pd.DataFrame(grid.cv_results_)['mean_fit_time'].sum(axis=0)
# Out:
# 36.09497559070587

# %% [markdown]
# # Execute CV

# %%
###define callbacks

    # keras_callbacks = [
    #     #early stopping
    #     tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=20, restore_best_weights=True),
    #     #csvlogger to track progress
    #     tf.keras.callbacks.CSVLogger(str(outdir/f"model_history_log_resample_{resample}.csv"), append=False),
    #     #create checkpoints
    #     tf.keras.callbacks.ModelCheckpoint(filepath=outdir/"checkpoint"/"checkpoint.ckpt",
    #                                     save_weights_only=True,
    #                                     verbose=1),
    #     #create logs
    #     tf.keras.callbacks.TensorBoard(log_dir=outdir/"tensorboard_logs", histogram_freq=1, write_graph=False, write_images=False),
    #     #adaptive learning rate
    #     # tf.keras.callbacks.LearningRateScheduler(adapt_lr)
    # ]







###fit the model
history = grid.fit(nxtr, ytr, 
                epochs=epochs,
                verbose=1,
                validation_split=0.2,
                callbacks=keras_callbacks
                )
#########################################
tuner = kt.GridSearch(build_model,
                       objective='val_loss',
                       # objective = ['val_mse','epoch_entropy_pred_mse','val_free_energy_pred_mse'],
                      directory=os.getcwd()+'/hyper_param_tunning',
                      overwrite=False,
                      project_name=f'{batch}')

# tuner.search(X_train_cv, [y_train_1_cv,y_train_2_cv,y_train_3_cv],
#                 epochs = epochs,
#                 batch_size=batch,
#                 verbose = 1,
#                 validation_data =(X_val_cv, [y_val_1_cv,y_val_2_cv,y_val_3_cv]),
#                 callbacks=[es, csv_logger, cp_callback, tensorboard_callback])
# tuner.results_summary()



trial=tuner.oracle.get_trial('0000')
# current_model=""
# current_model=tuner.hypermodel.build(trial.hyperparameters)
# load using trail.best_step() to find the optimal weights, trained version of the model.

trial=tuner.oracle.get_trial('0000')
current_model2=tuner.load_model(trial)

# https://stackoverflow.com/questions/67496915/reload-keras-tuner-trials-from-the-directory

# df=pd.DataFrame(current_model.predict(X_test_cv))
# df['new']=pd.DataFrame(current_model2.predict(X_test_cv))






#########################################




 # history = model.fit(X_train_cv, [y_train_1_cv,y_train_2_cv,y_train_3_cv],
 #                        epochs = epochs,
 #                        batch_size=batch,
 #                        verbose = 1,
 #                        validation_data =(X_val_cv, [y_val_1_cv,y_val_2_cv,y_val_3_cv]),
 #                        callbacks=[es, csv_logger, cp_callback, tensorboard_callback])

# Do we have to redefine the pipe? Think Dans code and data leakage
# NB! "model" must match the model__
pipe = Pipeline(steps=[("scaler", scaler), (f"{model_name}", model)])


# Load Data
# File ? and prop ?
y_1, y_2, y_3, y_4, x = load_data(file,prop)

# Initialise train test split:
train_test_split = ShuffleSplit(mc_cv, test_size=test_frac, random_state=1)

resample=0
# Monte Carlo CV:
for train_idx, test_idx in train_test_split.split(x):
    resample+=1
    
    # Separate data into training and test sets:
    x_train = x.iloc[train_idx]
    x_test = x.iloc[test_idx]
#     The next two lines (y) will vary depending on the CNN output
    y_train = [y_1.iloc[train_idx],y_2.iloc[train_idx],y_3.iloc[train_idx],y_4.iloc[train_idx]]
    y_test  = [y_1.iloc[test_idx] ,y_2.iloc[test_idx] ,y_3.iloc[test_idx] ,y_4.iloc[test_idx]]

    # Set up hyperparameter tuning using an exhaustive grid search 
    # for a pipe type model
    #    Define Model in loop (reset model and pipe
    rf_pipe = GridSearchCV(estimator = pipe,
                            param_grid = init_param_grid,
                            cv = hyper_cv,
                            scoring=scoring,
                            # refit = True,
                            refit = 'RMSD',
                            verbose = 2,
                            n_jobs = 1)
    

    # Train RF model:

    rf=rf_pipe.fit(x_train, y_train)
    name='rf_pipe'

# %% [markdown]
# ### Keras Tunner (grid Serarch)

# %%
#########################################
tuner = kt.GridSearch(build_model,
                       objective='val_loss',
                       # objective = ['val_mse','epoch_entropy_pred_mse','val_free_energy_pred_mse'],
                      directory=os.getcwd()+'/hyper_param_tunning',
                      overwrite=False,
                      project_name=f'1')

# tuner.search(X_train_cv, [y_train_1_cv,y_train_2_cv,y_train_3_cv],
#                 epochs = epochs,
#                 batch_size=batch,
#                 verbose = 1,
#                 validation_data =(X_val_cv, [y_val_1_cv,y_val_2_cv,y_val_3_cv]),
#                 callbacks=[es, csv_logger, cp_callback, tensorboard_callback])

# %%
# tuner.search(x_train, y_train[:3],
#                 epochs = epochs,
#                 batch_size=4,
#                 verbose = 2,
#                 # validation_data =(X_val_cv, [y_val_1_cv,y_val_2_cv,y_val_3_cv]),
#                  validation_split = 0.2,
#                 callbacks=[es, csv_logger, cp_callback, tensorboard_callback])
# tunner.

# %%
es1 = EarlyStopping(monitor='val_loss', 
                   mode='min', 
                   verbose=1, 
                   patience=20, 
                   restore_best_weights=True)
# CSV Logger
csv_logger1 = CSVLogger(f"{resultdir}/csv_logger1/model_history_log_resample_{resample}.csv", 
                       append=True)
# CP_callbacks
# https://www.tensorflow.org/tutorials/keras/save_and_load

# # Include the epoch in the file name (uses `str.format`)
# checkpoint_path = "training_2/cp-{epoch:04d}.ckpt"
# checkpoint_dir = os.path.dirname(checkpoint_path)


cp_callback1 = tf.keras.callbacks.ModelCheckpoint(filepath=f'{resultdir}/model_checkpoint1/training_{resample}/cp.ckpt',
                                                 save_weights_only=True,
                                                 verbose=1)
# TensorBoard
tensorboard_callback1 = tf.keras.callbacks.TensorBoard(log_dir=f'{resultdir}/tensorboard_logs1/{resample}', #/{batch}', # _ADAPTIVELEARNIGNRATE_01_10_Dense3_64_3CNN_lr_3_es
                                                      update_freq = 1,
                                                      # histogram_freq=1, 
                                                      write_graph=False, 
                                                      write_images=False)
# https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/TensorBoard

# Covert to list and provide to Keras Regressor
keras_callbacks1 = [es1, csv_logger1, cp_callback1,tensorboard_callback1]

# %% [markdown]
# ### Dev Keras Tunner

# %%
 for hp_train_idx, hp_val_idx in train_test_split.split(pd.DataFrame(x_train)):
        x_hp_train, x_hp_val, y_hp_train, y_hp_val = wrapped_train_val_split(hp_train_idx,hp_val_idx,pd.DataFrame(x_train),y_train)
    
        tuner.search(x_hp_train, y_hp_train[:3],
                    epochs = epochs,
                    batch_size=4,
                    verbose = 2,
                    validation_data =(x_hp_val, y_hp_val[:3]),
                     # validation_split = 0.2,
                    callbacks=[es1, csv_logger1, cp_callback1, tensorboard_callback1])

# %%
pd.DataFrame(x_train)
for hp_train_idx, hp_val_idx in train_test_split.split(pd.DataFrame(x_train)):
    x_hp_train, x_hp_val, y_hp_train, y_hp_val = wrapped_train_val_split(hp_train_idx,hp_val_idx,pd.DataFrame(x_train),y_train)
print('train', type(x_hp_train), x_hp_train.shape, '\n' ,
  'test', type(x_hp_val),x_hp_val.shape, '\n' ,
  'y_train', len(y_hp_train), type(y_hp_train[0]), y_hp_train[0].shape,'\n',
  type(y_hp_train[1]), y_hp_train[1].shape,'\n',
  type(y_hp_train[2]), y_hp_train[2].shape,'\n',
  type(y_hp_train[3]), y_hp_train[3].shape,'\n',
  'y_test', len(y_hp_val), type(y_hp_val[0]), y_hp_val[0].shape,'\n',
  type(y_hp_val[1]), y_hp_val[1].shape,'\n',
  type(y_hp_val[2]), y_hp_val[2].shape,'\n',
  type(y_hp_val[3]), y_hp_val[3].shape,'\n')
# Out:
# train <class 'numpy.ndarray'> (149, 250)
#  test <class 'pandas.core.frame.DataFrame'> (64, 250)
#  y_train 4 <class 'numpy.ndarray'> (149,)
#  <class 'numpy.ndarray'> (149,)
#  <class 'numpy.ndarray'> (149,)
#  <class 'numpy.ndarray'> (149,)
#  y_test 4 <class 'numpy.ndarray'> (64,)
#  <class 'numpy.ndarray'> (64,)
#  <class 'numpy.ndarray'> (64,)
#  <class 'numpy.ndarray'> (64,)

# %%
def wrapped_train_val_split(hp_train_idx,hp_val_idx,x_train,y_train):
    x_hp_train = x_train.iloc[hp_train_idx].to_numpy()
    x_hp_val = x_train.iloc[hp_val_idx]
#     The next two lines (y) will vary depending on the CNN output

    y_train_df=[]
    for y_i in y_train:
       y_train_df.append(pd.DataFrame(y_i))

    y_train=y_train_df
    y_hp_train = [y_train[0].iloc[hp_train_idx],y_train[1].iloc[hp_train_idx],y_train[2].iloc[hp_train_idx],y_train[3].iloc[hp_train_idx]]
    y_hp_val  = [y_train[0].iloc[hp_val_idx] ,y_train[1].iloc[hp_val_idx] ,y_train[2].iloc[hp_val_idx] ,y_train[3].iloc[hp_val_idx]]
    
    # return padding(x_train), padding(x_test), df_np(y_train), df_np(y_test)
    return x_hp_train, x_hp_val, df_np(y_hp_train), df_np(y_hp_val)

# %%
def wrapped_train_val_split(hp_train_idx,hp_val_idx,x_train,y_train):
    x_hp_train = x_train.iloc[hp_train_idx].to_numpy()
    x_hp_val = x_train.iloc[hp_val_idx]
#     The next two lines (y) will vary depending on the CNN output

    y_train_df=[]
    for y_i in y_train:
       y_train_df.append(pd.DataFrame(y_i))

    y_train=y_train_df
    y_hp_train = [y_train[0].iloc[hp_train_idx],y_train[1].iloc[hp_train_idx],y_train[2].iloc[hp_train_idx],y_train[3].iloc[hp_train_idx]]
    y_hp_val  = [y_train[0].iloc[hp_val_idx] ,y_train[1].iloc[hp_val_idx] ,y_train[2].iloc[hp_val_idx] ,y_train[3].iloc[hp_val_idx]]
    
    # return padding(x_train), padding(x_test), df_np(y_train), df_np(y_test)
    return x_hp_train, x_hp_val, df_np(y_hp_train), df_np(y_hp_val)
